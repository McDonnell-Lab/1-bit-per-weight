# %% [markdown]
# # Tensorflow.keras implementation of one-bit-per-weight CNN for CIFAR 100
# ##  https://arxiv.org/abs/1802.08530
# ## M. D. McDonnell,
# ## Training wide residual networks for deployment using a single bit for each weight
# ## ICLR, 2018

# %%
# select a GPU
import os
os.environ["CUDA_DEVICE_ORDER"] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = '4'

import numpy as np
import h5py
import matplotlib.pyplot as plt
import copy
from scipy.io import savemat,loadmat
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)

import tensorflow
print('Tensorflow version = ',tensorflow.__version__)
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import LearningRateScheduler, History

#from tensorflow.keras import backend as K

from ResNetModel import resnet
from Utils import cutout,LR_WarmRestart,GetDataGen,plot_history
# Out:
# Tensorflow version =  1.13.1

# %%
#params
#WhichDataSet = 'CIFAR10'
WhichDataSet = 'CIFAR100'
init_lr = 0.1
epochs = 254
batch_size = 125
My_wd=5e-4/2
resnet_width = 10
resnet_depth = 20
UseBinary=True
UseCutout=True
Loss = 'categorical_crossentropy'
Optimizer = SGD(lr=init_lr,decay=0.0, momentum=0.9, nesterov=False)
Metrics = ['accuracy']
ModelsPath = 'TrainedModels/Tensorflow.keras/'
# Out:
# WARNING:tensorflow:From /home/mdmcdonn/anaconda3/envs/April2019/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
#load and prepare data
if WhichDataSet == 'CIFAR10':
    (x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.cifar10.load_data()
else:
    (x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.cifar100.load_data()
num_classes = np.unique(y_train).shape[0]
K_train = x_train.shape[0]
input_shape = x_train.shape[1:]
x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0
y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

# %%
#fdefine a datagen or generating training samples with flip and pad/crop augmentation, and if set to True, with cutout augmentation
dataGenerator = GetDataGen(UseCutout)

#define and compile the model
model = resnet(UseBinary,input_shape=input_shape, depth=resnet_depth, num_classes=num_classes,wd=My_wd,width=resnet_width)
model.compile(loss=Loss ,optimizer = Optimizer, metrics = Metrics)

#print  the model
model.summary()

#define the learnng rate schedule
steps_per_epoch = int(np.floor(K_train / batch_size))
lr_scheduler = LR_WarmRestart(nbatch=steps_per_epoch,
                              initial_lr=init_lr, min_lr=init_lr*1e-4,
                              epochs_restart = [1.0,3.0, 7.0, 15.0, 31.0, 63.0,127.0,255.0]) 

#define callbacks
history = History()
callbacks = [lr_scheduler,history]
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# batch_normalization_v1 (BatchNo (None, 32, 32, 3)    12          input_1[0][0]
# __________________________________________________________________________________________________
# binary_conv2d (BinaryConv2D)    (None, 32, 32, 160)  4320        batch_normalization_v1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_1 (Batch (None, 32, 32, 160)  320         binary_conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 160)  0           batch_normalization_v1_1[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_1 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_2 (Batch (None, 32, 32, 160)  320         binary_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_2[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_2 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 160)  0           binary_conv2d_2[0][0]
#                                                                  binary_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_3 (Batch (None, 32, 32, 160)  320         add[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_3[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_3 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_4 (Batch (None, 32, 32, 160)  320         binary_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_4[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_4 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 160)  0           binary_conv2d_4[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_5 (Batch (None, 32, 32, 160)  320         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_5[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_5 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_6 (Batch (None, 32, 32, 160)  320         binary_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_6[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_6 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 160)  0           binary_conv2d_6[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_7 (Batch (None, 32, 32, 160)  320         add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_7[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_7 (BinaryConv2D)  (None, 16, 16, 320)  460800      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_8 (Batch (None, 16, 16, 320)  640         binary_conv2d_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 16, 16, 160)  0           add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 320)  0           batch_normalization_v1_8[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 16, 16, 160)  0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_8 (BinaryConv2D)  (None, 16, 16, 320)  921600      activation_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 320)  0           average_pooling2d[0][0]
#                                                                  lambda[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 320)  0           binary_conv2d_8[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_9 (Batch (None, 16, 16, 320)  640         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 320)  0           batch_normalization_v1_9[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_9 (BinaryConv2D)  (None, 16, 16, 320)  921600      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_10 (Batc (None, 16, 16, 320)  640         binary_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 320)  0           batch_normalization_v1_10[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_10 (BinaryConv2D) (None, 16, 16, 320)  921600      activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 320)  0           binary_conv2d_10[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_11 (Batc (None, 16, 16, 320)  640         add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 320)  0           batch_normalization_v1_11[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_11 (BinaryConv2D) (None, 16, 16, 320)  921600      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_12 (Batc (None, 16, 16, 320)  640         binary_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 320)  0           batch_normalization_v1_12[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_12 (BinaryConv2D) (None, 16, 16, 320)  921600      activation_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 320)  0           binary_conv2d_12[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_13 (Batc (None, 16, 16, 320)  640         add_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 320)  0           batch_normalization_v1_13[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_13 (BinaryConv2D) (None, 8, 8, 640)    1843200     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_14 (Batc (None, 8, 8, 640)    1280        binary_conv2d_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 8, 8, 320)    0           add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_14[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 8, 8, 320)    0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_14 (BinaryConv2D) (None, 8, 8, 640)    3686400     activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 640)    0           average_pooling2d_1[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 640)    0           binary_conv2d_14[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_15 (Batc (None, 8, 8, 640)    1280        add_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_15[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_15 (BinaryConv2D) (None, 8, 8, 640)    3686400     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_16 (Batc (None, 8, 8, 640)    1280        binary_conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_16[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_16 (BinaryConv2D) (None, 8, 8, 640)    3686400     activation_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 640)    0           binary_conv2d_16[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_17 (Batc (None, 8, 8, 640)    1280        add_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_17[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_17 (BinaryConv2D) (None, 8, 8, 640)    3686400     activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_18 (Batc (None, 8, 8, 640)    1280        binary_conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_18[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_18 (BinaryConv2D) (None, 8, 8, 640)    3686400     activation_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 640)    0           binary_conv2d_18[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_19 (Batc (None, 8, 8, 640)    1280        add_8[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_19[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_19 (BinaryConv2D) (None, 8, 8, 100)    64000       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_20 (Batc (None, 8, 8, 100)    200         binary_conv2d_19[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 100)          0           batch_normalization_v1_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 100)          0           global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 26,808,692
# Trainable params: 26,794,726
# Non-trainable params: 13,966
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(dataGenerator.flow(x_train, y_train, batch_size=batch_size),
                              validation_data=(x_test, y_test),
                              epochs=epochs,
                              verbose=1,
                              callbacks=callbacks,
                              steps_per_epoch =steps_per_epoch)
# Out:
# WARNING:tensorflow:From /home/mdmcdonn/anaconda3/envs/April2019/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 1/254
# 10000/10000 [==============================] - 7s 659us/sample - loss: 6.3269 - acc: 0.1440
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 109s 273ms/step - loss: 6.8190 - acc: 0.1359 - val_loss: 6.3269 - val_acc: 0.1440
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 2/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 5.3427 - acc: 0.3064
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 105s 263ms/step - loss: 5.7201 - acc: 0.2465 - val_loss: 5.3427 - val_acc: 0.3064
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 3/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 5.2199 - acc: 0.1972
#
#  End of Epoch Learning Rate = 0.085357
# 400/400 [==============================] - 105s 262ms/step - loss: 5.3534 - acc: 0.2450 - val_loss: 5.2199 - val_acc: 0.1972
#
#  Start of Epoch Learning Rate = 0.085357
# Epoch 4/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 4.3311 - acc: 0.3114
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 105s 262ms/step - loss: 4.4846 - acc: 0.3212 - val_loss: 4.3311 - val_acc: 0.3114
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 5/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 3.6141 - acc: 0.4510
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 105s 262ms/step - loss: 3.8989 - acc: 0.3988 - val_loss: 3.6141 - val_acc: 0.4510
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 6/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 3.2302 - acc: 0.5193
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 105s 262ms/step - loss: 3.5284 - acc: 0.4652 - val_loss: 3.2302 - val_acc: 0.5193
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 7/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 4.0409 - acc: 0.2915
#
#  End of Epoch Learning Rate = 0.096194
# 400/400 [==============================] - 105s 262ms/step - loss: 3.8317 - acc: 0.3712 - val_loss: 4.0409 - val_acc: 0.2915
#
#  Start of Epoch Learning Rate = 0.096194
# Epoch 8/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 3.4967 - acc: 0.3741
#
#  End of Epoch Learning Rate = 0.085357
# 400/400 [==============================] - 105s 262ms/step - loss: 3.4087 - acc: 0.4189 - val_loss: 3.4967 - val_acc: 0.3741
#
#  Start of Epoch Learning Rate = 0.085357
# Epoch 9/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 3.0608 - acc: 0.4493
#
#  End of Epoch Learning Rate = 0.069137
# 400/400 [==============================] - 105s 262ms/step - loss: 3.0852 - acc: 0.4617 - val_loss: 3.0608 - val_acc: 0.4493
#
#  Start of Epoch Learning Rate = 0.069137
# Epoch 10/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 2.8459 - acc: 0.4670
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 105s 262ms/step - loss: 2.8173 - acc: 0.5007 - val_loss: 2.8459 - val_acc: 0.4670
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 11/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 2.7087 - acc: 0.4901
#
#  End of Epoch Learning Rate = 0.030873
# 400/400 [==============================] - 105s 262ms/step - loss: 2.5867 - acc: 0.5369 - val_loss: 2.7087 - val_acc: 0.4901
#
#  Start of Epoch Learning Rate = 0.030873
# Epoch 12/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 2.2894 - acc: 0.5849
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 105s 261ms/step - loss: 2.3582 - acc: 0.5823 - val_loss: 2.2894 - val_acc: 0.5849
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 13/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 1.9642 - acc: 0.6522
#
#  End of Epoch Learning Rate = 0.003816
# 400/400 [==============================] - 105s 262ms/step - loss: 2.1574 - acc: 0.6216 - val_loss: 1.9642 - val_acc: 0.6522
#
#  Start of Epoch Learning Rate = 0.003816
# Epoch 14/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 1.8831 - acc: 0.6683
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 105s 262ms/step - loss: 2.0144 - acc: 0.6543 - val_loss: 1.8831 - val_acc: 0.6683
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 15/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 3.4365 - acc: 0.3251
#
#  End of Epoch Learning Rate = 0.099039
# 400/400 [==============================] - 105s 262ms/step - loss: 2.7644 - acc: 0.4874 - val_loss: 3.4365 - val_acc: 0.3251
#
#  Start of Epoch Learning Rate = 0.099039
# Epoch 16/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 3.0502 - acc: 0.4236
#
#  End of Epoch Learning Rate = 0.096194
# 400/400 [==============================] - 105s 262ms/step - loss: 2.6652 - acc: 0.5025 - val_loss: 3.0502 - val_acc: 0.4236
#
#  Start of Epoch Learning Rate = 0.096194
# Epoch 17/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 2.6624 - acc: 0.4881
#
#  End of Epoch Learning Rate = 0.091574
# 400/400 [==============================] - 105s 262ms/step - loss: 2.5775 - acc: 0.5196 - val_loss: 2.6624 - val_acc: 0.4881
#
#  Start of Epoch Learning Rate = 0.091574
# Epoch 18/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 2.9893 - acc: 0.4184
#
#  End of Epoch Learning Rate = 0.085357
# 400/400 [==============================] - 105s 262ms/step - loss: 2.4991 - acc: 0.5332 - val_loss: 2.9893 - val_acc: 0.4184
#
#  Start of Epoch Learning Rate = 0.085357
# Epoch 19/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 3.0428 - acc: 0.4157
#
#  End of Epoch Learning Rate = 0.077781
# 400/400 [==============================] - 105s 262ms/step - loss: 2.4101 - acc: 0.5501 - val_loss: 3.0428 - val_acc: 0.4157
#
#  Start of Epoch Learning Rate = 0.077781
# Epoch 20/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 2.5378 - acc: 0.4980
#
#  End of Epoch Learning Rate = 0.069137
# 400/400 [==============================] - 105s 262ms/step - loss: 2.3331 - acc: 0.5629 - val_loss: 2.5378 - val_acc: 0.4980
#
#  Start of Epoch Learning Rate = 0.069137
# Epoch 21/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 2.5226 - acc: 0.5042
#
#  End of Epoch Learning Rate = 0.059759
# 400/400 [==============================] - 105s 261ms/step - loss: 2.2516 - acc: 0.5797 - val_loss: 2.5226 - val_acc: 0.5042
#
#  Start of Epoch Learning Rate = 0.059759
# Epoch 22/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 2.3545 - acc: 0.5301
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 105s 262ms/step - loss: 2.1663 - acc: 0.5950 - val_loss: 2.3545 - val_acc: 0.5301
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 23/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 2.5438 - acc: 0.5054
#
#  End of Epoch Learning Rate = 0.040251
# 400/400 [==============================] - 105s 261ms/step - loss: 2.0666 - acc: 0.6151 - val_loss: 2.5438 - val_acc: 0.5054
#
#  Start of Epoch Learning Rate = 0.040251
# Epoch 24/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 2.1600 - acc: 0.5871
#
#  End of Epoch Learning Rate = 0.030873
# 400/400 [==============================] - 105s 262ms/step - loss: 1.9444 - acc: 0.6394 - val_loss: 2.1600 - val_acc: 0.5871
#
#  Start of Epoch Learning Rate = 0.030873
# Epoch 25/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 1.9063 - acc: 0.6294
#
#  End of Epoch Learning Rate = 0.022229
# 400/400 [==============================] - 105s 262ms/step - loss: 1.8191 - acc: 0.6650 - val_loss: 1.9063 - val_acc: 0.6294
#
#  Start of Epoch Learning Rate = 0.022229
# Epoch 26/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.7594 - acc: 0.6646
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 105s 262ms/step - loss: 1.6980 - acc: 0.6952 - val_loss: 1.7594 - val_acc: 0.6646
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 27/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 1.6198 - acc: 0.6952
#
#  End of Epoch Learning Rate = 0.008436
# 400/400 [==============================] - 105s 262ms/step - loss: 1.5714 - acc: 0.7232 - val_loss: 1.6198 - val_acc: 0.6952
#
#  Start of Epoch Learning Rate = 0.008436
# Epoch 28/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 1.4952 - acc: 0.7253
#
#  End of Epoch Learning Rate = 0.003816
# 400/400 [==============================] - 105s 262ms/step - loss: 1.4576 - acc: 0.7495 - val_loss: 1.4952 - val_acc: 0.7253
#
#  Start of Epoch Learning Rate = 0.003816
# Epoch 29/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 1.3822 - acc: 0.7475
#
#  End of Epoch Learning Rate = 0.000971
# 400/400 [==============================] - 105s 262ms/step - loss: 1.3643 - acc: 0.7729 - val_loss: 1.3822 - val_acc: 0.7475
#
#  Start of Epoch Learning Rate = 0.000971
# Epoch 30/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 1.3624 - acc: 0.7514
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 105s 262ms/step - loss: 1.3058 - acc: 0.7878 - val_loss: 1.3624 - val_acc: 0.7514
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 31/254
# 10000/10000 [==============================] - 6s 610us/sample - loss: 3.1275 - acc: 0.3720
#
#  End of Epoch Learning Rate = 0.099759
# 400/400 [==============================] - 104s 261ms/step - loss: 2.4190 - acc: 0.5331 - val_loss: 3.1275 - val_acc: 0.3720
#
#  Start of Epoch Learning Rate = 0.099759
# Epoch 32/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 2.9681 - acc: 0.4081
#
#  End of Epoch Learning Rate = 0.099039
# 400/400 [==============================] - 105s 261ms/step - loss: 2.4088 - acc: 0.5449 - val_loss: 2.9681 - val_acc: 0.4081
#
#  Start of Epoch Learning Rate = 0.099039
# Epoch 33/254
# 10000/10000 [==============================] - 6s 610us/sample - loss: 3.3473 - acc: 0.3623
#
#  End of Epoch Learning Rate = 0.097847
# 400/400 [==============================] - 104s 261ms/step - loss: 2.3954 - acc: 0.5520 - val_loss: 3.3473 - val_acc: 0.3623
#
#  Start of Epoch Learning Rate = 0.097847
# Epoch 34/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 2.6774 - acc: 0.4749
#
#  End of Epoch Learning Rate = 0.096194
# 400/400 [==============================] - 105s 262ms/step - loss: 2.3755 - acc: 0.5587 - val_loss: 2.6774 - val_acc: 0.4749
#
#  Start of Epoch Learning Rate = 0.096194
# Epoch 35/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 3.0632 - acc: 0.4146
#
#  End of Epoch Learning Rate = 0.094097
# 400/400 [==============================] - 105s 262ms/step - loss: 2.3517 - acc: 0.5686 - val_loss: 3.0632 - val_acc: 0.4146
#
#  Start of Epoch Learning Rate = 0.094097
# Epoch 36/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 3.0220 - acc: 0.4196
#
#  End of Epoch Learning Rate = 0.091574
# 400/400 [==============================] - 105s 262ms/step - loss: 2.3375 - acc: 0.5720 - val_loss: 3.0220 - val_acc: 0.4196
#
#  Start of Epoch Learning Rate = 0.091574
# Epoch 37/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 3.2738 - acc: 0.3675
#
#  End of Epoch Learning Rate = 0.088652
# 400/400 [==============================] - 105s 262ms/step - loss: 2.3214 - acc: 0.5783 - val_loss: 3.2738 - val_acc: 0.3675
#
#  Start of Epoch Learning Rate = 0.088652
# Epoch 38/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 3.1634 - acc: 0.3818
#
#  End of Epoch Learning Rate = 0.085357
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2918 - acc: 0.5818 - val_loss: 3.1634 - val_acc: 0.3818
#
#  Start of Epoch Learning Rate = 0.085357
# Epoch 39/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 2.8735 - acc: 0.4497
#
#  End of Epoch Learning Rate = 0.081721
# 400/400 [==============================] - 105s 261ms/step - loss: 2.2533 - acc: 0.5913 - val_loss: 2.8735 - val_acc: 0.4497
#
#  Start of Epoch Learning Rate = 0.081721
# Epoch 40/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 3.3801 - acc: 0.3566
#
#  End of Epoch Learning Rate = 0.077781
# 400/400 [==============================] - 105s 261ms/step - loss: 2.2299 - acc: 0.5954 - val_loss: 3.3801 - val_acc: 0.3566
#
#  Start of Epoch Learning Rate = 0.077781
# Epoch 41/254
# 10000/10000 [==============================] - 6s 616us/sample - loss:
254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 3.1906 - acc: 0.3830
#
#  End of Epoch Learning Rate = 0.075708
# 400/400 [==============================] - 105s 262ms/step - loss: 2.1344 - acc: 0.6268 - val_loss: 3.1906 - val_acc: 0.3830
#
#  Start of Epoch Learning Rate = 0.075708
# Epoch 84/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 2.8353 - acc: 0.4690
#
#  End of Epoch Learning Rate = 0.073572
# 400/400 [==============================] - 105s 262ms/step - loss: 2.1078 - acc: 0.6337 - val_loss: 2.8353 - val_acc: 0.4690
#
#  Start of Epoch Learning Rate = 0.073572
# Epoch 85/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 3.0102 - acc: 0.4437
#
#  End of Epoch Learning Rate = 0.071381
# 400/400 [==============================] - 105s 262ms/step - loss: 2.0914 - acc: 0.6355 - val_loss: 3.0102 - val_acc: 0.4437
#
#  Start of Epoch Learning Rate = 0.071381
# Epoch 86/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 2.8881 - acc: 0.4574
#
#  End of Epoch Learning Rate = 0.069137
# 400/400 [==============================] - 105s 261ms/step - loss: 2.0626 - acc: 0.6419 - val_loss: 2.8881 - val_acc: 0.4574
#
#  Start of Epoch Learning Rate = 0.069137
# Epoch 87/254
# 10000/10000 [==============================] - 6s 610us/sample - loss: 2.7646 - acc: 0.4808
#
#  End of Epoch Learning Rate = 0.066848
# 400/400 [==============================] - 105s 261ms/step - loss: 2.0374 - acc: 0.6462 - val_loss: 2.7646 - val_acc: 0.4808
#
#  Start of Epoch Learning Rate = 0.066848
# Epoch 88/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 2.8505 - acc: 0.4581
#
#  End of Epoch Learning Rate = 0.064518
# 400/400 [==============================] - 105s 262ms/step - loss: 2.0188 - acc: 0.6500 - val_loss: 2.8505 - val_acc: 0.4581
#
#  Start of Epoch Learning Rate = 0.064518
# Epoch 89/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 2.3747 - acc: 0.5561
#
#  End of Epoch Learning Rate = 0.062153
# 400/400 [==============================] - 105s 261ms/step - loss: 2.0063 - acc: 0.6486 - val_loss: 2.3747 - val_acc: 0.5561
#
#  Start of Epoch Learning Rate = 0.062153
# Epoch 90/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 2.5364 - acc: 0.5234
#
#  End of Epoch Learning Rate = 0.059759
# 400/400 [==============================] - 105s 262ms/step - loss: 1.9718 - acc: 0.6569 - val_loss: 2.5364 - val_acc: 0.5234
#
#  Start of Epoch Learning Rate = 0.059759
# Epoch 91/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 2.3910 - acc: 0.5617
#
#  End of Epoch Learning Rate = 0.057341
# 400/400 [==============================] - 105s 261ms/step - loss: 1.9486 - acc: 0.6609 - val_loss: 2.3910 - val_acc: 0.5617
#
#  Start of Epoch Learning Rate = 0.057341
# Epoch 92/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 2.6907 - acc: 0.4851
#
#  End of Epoch Learning Rate = 0.054905
# 400/400 [==============================] - 105s 262ms/step - loss: 1.9206 - acc: 0.6662 - val_loss: 2.6907 - val_acc: 0.4851
#
#  Start of Epoch Learning Rate = 0.054905
# Epoch 93/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 2.1390 - acc: 0.5930
#
#  End of Epoch Learning Rate = 0.052458
# 400/400 [==============================] - 105s 262ms/step - loss: 1.8947 - acc: 0.6717 - val_loss: 2.1390 - val_acc: 0.5930
#
#  Start of Epoch Learning Rate = 0.052458
# Epoch 94/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 2.9475 - acc: 0.4395
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 105s 262ms/step - loss: 1.8620 - acc: 0.6761 - val_loss: 2.9475 - val_acc: 0.4395
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 95/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 2.5058 - acc: 0.5195
#
#  End of Epoch Learning Rate = 0.047552
# 400/400 [==============================] - 105s 262ms/step - loss: 1.8305 - acc: 0.6836 - val_loss: 2.5058 - val_acc: 0.5195
#
#  Start of Epoch Learning Rate = 0.047552
# Epoch 96/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 2.1294 - acc: 0.6011
#
#  End of Epoch Learning Rate = 0.045105
# 400/400 [==============================] - 104s 261ms/step - loss: 1.8000 - acc: 0.6902 - val_loss: 2.1294 - val_acc: 0.6011
#
#  Start of Epoch Learning Rate = 0.045105
# Epoch 97/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 2.4253 - acc: 0.5282
#
#  End of Epoch Learning Rate = 0.042669
# 400/400 [==============================] - 105s 261ms/step - loss: 1.7635 - acc: 0.6952 - val_loss: 2.4253 - val_acc: 0.5282
#
#  Start of Epoch Learning Rate = 0.042669
# Epoch 98/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 2.3401 - acc: 0.5574
#
#  End of Epoch Learning Rate = 0.040251
# 400/400 [==============================] - 104s 261ms/step - loss: 1.7238 - acc: 0.7047 - val_loss: 2.3401 - val_acc: 0.5574
#
#  Start of Epoch Learning Rate = 0.040251
# Epoch 99/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 2.5568 - acc: 0.5251
#
#  End of Epoch Learning Rate = 0.037857
# 400/400 [==============================] - 104s 261ms/step - loss: 1.6971 - acc: 0.7072 - val_loss: 2.5568 - val_acc: 0.5251
#
#  Start of Epoch Learning Rate = 0.037857
# Epoch 100/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 2.4423 - acc: 0.5338
#
#  End of Epoch Learning Rate = 0.035492
# 400/400 [==============================] - 104s 261ms/step - loss: 1.6579 - acc: 0.7163 - val_loss: 2.4423 - val_acc: 0.5338
#
#  Start of Epoch Learning Rate = 0.035492
# Epoch 101/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 2.1669 - acc: 0.5929
#
#  End of Epoch Learning Rate = 0.033162
# 400/400 [==============================] - 104s 261ms/step - loss: 1.6233 - acc: 0.7213 - val_loss: 2.1669 - val_acc: 0.5929
#
#  Start of Epoch Learning Rate = 0.033162
# Epoch 102/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 2.0320 - acc: 0.6185
#
#  End of Epoch Learning Rate = 0.030873
# 400/400 [==============================] - 105s 261ms/step - loss: 1.5917 - acc: 0.7279 - val_loss: 2.0320 - val_acc: 0.6185
#
#  Start of Epoch Learning Rate = 0.030873
# Epoch 103/254
# 10000/10000 [==============================] - 6s 608us/sample - loss: 2.3301 - acc: 0.5516
#
#  End of Epoch Learning Rate = 0.028629
# 400/400 [==============================] - 104s 261ms/step - loss: 1.5430 - acc: 0.7391 - val_loss: 2.3301 - val_acc: 0.5516
#
#  Start of Epoch Learning Rate = 0.028629
# Epoch 104/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 1.9960 - acc: 0.6277
#
#  End of Epoch Learning Rate = 0.026438
# 400/400 [==============================] - 104s 261ms/step - loss: 1.5061 - acc: 0.7462 - val_loss: 1.9960 - val_acc: 0.6277
#
#  Start of Epoch Learning Rate = 0.026438
# Epoch 105/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 1.8872 - acc: 0.6504
#
#  End of Epoch Learning Rate = 0.024302
# 400/400 [==============================] - 105s 261ms/step - loss: 1.4588 - acc: 0.7545 - val_loss: 1.8872 - val_acc: 0.6504
#
#  Start of Epoch Learning Rate = 0.024302
# Epoch 106/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.9309 - acc: 0.6276
#
#  End of Epoch Learning Rate = 0.022229
# 400/400 [==============================] - 105s 262ms/step - loss: 1.4214 - acc: 0.7651 - val_loss: 1.9309 - val_acc: 0.6276
#
#  Start of Epoch Learning Rate = 0.022229
# Epoch 107/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 2.0354 - acc: 0.6098
#
#  End of Epoch Learning Rate = 0.020223
# 400/400 [==============================] - 105s 261ms/step - loss: 1.3775 - acc: 0.7718 - val_loss: 2.0354 - val_acc: 0.6098
#
#  Start of Epoch Learning Rate = 0.020223
# Epoch 108/254
# 10000/10000 [==============================] - 6s 610us/sample - loss: 1.8306 - acc: 0.6563
#
#  End of Epoch Learning Rate = 0.018289
# 400/400 [==============================] - 105s 262ms/step - loss: 1.3357 - acc: 0.7801 - val_loss: 1.8306 - val_acc: 0.6563
#
#  Start of Epoch Learning Rate = 0.018289
# Epoch 109/254
# 10000/10000 [==============================] - 6s 610us/sample - loss: 1.7262 - acc: 0.6724
#
#  End of Epoch Learning Rate = 0.016430
# 400/400 [==============================] - 105s 262ms/step - loss: 1.2950 - acc: 0.7927 - val_loss: 1.7262 - val_acc: 0.6724
#
#  Start of Epoch Learning Rate = 0.016430
# Epoch 110/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 1.7626 - acc: 0.6691
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 105s 262ms/step - loss: 1.2434 - acc: 0.8028 - val_loss: 1.7626 - val_acc: 0.6691
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 111/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 1.5501 - acc: 0.7153
#
#  End of Epoch Learning Rate = 0.012961
# 400/400 [==============================] - 105s 262ms/step - loss: 1.1925 - acc: 0.8149 - val_loss: 1.5501 - val_acc: 0.7153
#
#  Start of Epoch Learning Rate = 0.012961
# Epoch 112/254
# 10000/10000 [==============================] - 6s 606us/sample - loss: 1.5347 - acc: 0.7180
#
#  End of Epoch Learning Rate = 0.011358
# 400/400 [==============================] - 105s 261ms/step - loss: 1.1545 - acc: 0.8239 - val_loss: 1.5347 - val_acc: 0.7180
#
#  Start of Epoch Learning Rate = 0.011358
# Epoch 113/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 1.5562 - acc: 0.7200
#
#  End of Epoch Learning Rate = 0.009849
# 400/400 [==============================] - 105s 262ms/step - loss: 1.1016 - acc: 0.8353 - val_loss: 1.5562 - val_acc: 0.7200
#
#  Start of Epoch Learning Rate = 0.009849
# Epoch 114/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.5206 - acc: 0.7225
#
#  End of Epoch Learning Rate = 0.008436
# 400/400 [==============================] - 105s 262ms/step - loss: 1.0576 - acc: 0.8453 - val_loss: 1.5206 - val_acc: 0.7225
#
#  Start of Epoch Learning Rate = 0.008436
# Epoch 115/254
# 10000/10000 [==============================] - 6s 612us/sample - loss:
254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 1.1726 - acc: 0.8013
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 105s 262ms/step - loss: 0.7250 - acc: 0.9303 - val_loss: 1.1726 - val_acc: 0.8013
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 127/254
# 10000/10000 [==============================] - 6s 609us/sample - loss: 3.9173 - acc: 0.2429
#
#  End of Epoch Learning Rate = 0.099985
# 400/400 [==============================] - 105s 262ms/step - loss: 2.3575 - acc: 0.5448 - val_loss: 3.9173 - val_acc: 0.2429
#
#  Start of Epoch Learning Rate = 0.099985
# Epoch 128/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 3.0382 - acc: 0.4166
#
#  End of Epoch Learning Rate = 0.099940
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2903 - acc: 0.5742 - val_loss: 3.0382 - val_acc: 0.4166
#
#  Start of Epoch Learning Rate = 0.099940
# Epoch 129/254
# 10000/10000 [==============================] - 6s 610us/sample - loss: 2.9745 - acc: 0.4498
#
#  End of Epoch Learning Rate = 0.099865
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2782 - acc: 0.5878 - val_loss: 2.9745 - val_acc: 0.4498
#
#  Start of Epoch Learning Rate = 0.099865
# Epoch 130/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 3.4012 - acc: 0.3545
#
#  End of Epoch Learning Rate = 0.099759
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2685 - acc: 0.5976 - val_loss: 3.4012 - val_acc: 0.3545
#
#  Start of Epoch Learning Rate = 0.099759
# Epoch 131/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 2.8899 - acc: 0.4642
#
#  End of Epoch Learning Rate = 0.099624
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2758 - acc: 0.6005 - val_loss: 2.8899 - val_acc: 0.4642
#
#  Start of Epoch Learning Rate = 0.099624
# Epoch 132/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 2.9351 - acc: 0.4649
#
#  End of Epoch Learning Rate = 0.099459
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2813 - acc: 0.6053 - val_loss: 2.9351 - val_acc: 0.4649
#
#  Start of Epoch Learning Rate = 0.099459
# Epoch 133/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 3.5380 - acc: 0.3359
#
#  End of Epoch Learning Rate = 0.099264
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2772 - acc: 0.6046 - val_loss: 3.5380 - val_acc: 0.3359
#
#  Start of Epoch Learning Rate = 0.099264
# Epoch 134/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 2.8813 - acc: 0.4617
#
#  End of Epoch Learning Rate = 0.099039
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2889 - acc: 0.6064 - val_loss: 2.8813 - val_acc: 0.4617
#
#  Start of Epoch Learning Rate = 0.099039
# Epoch 135/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 3.0405 - acc: 0.4522
#
#  End of Epoch Learning Rate = 0.098785
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2764 - acc: 0.6104 - val_loss: 3.0405 - val_acc: 0.4522
#
#  Start of Epoch Learning Rate = 0.098785
# Epoch 136/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 3.1460 - acc: 0.4178
#
#  End of Epoch Learning Rate = 0.098502
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2856 - acc: 0.6097 - val_loss: 3.1460 - val_acc: 0.4178
#
#  Start of Epoch Learning Rate = 0.098502
# Epoch 137/254
# 10000/10000 [==============================] - 6s 610us/sample - loss: 3.5704 - acc: 0.3530
#
#  End of Epoch Learning Rate = 0.098189
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2756 - acc: 0.6118 - val_loss: 3.5704 - val_acc: 0.3530
#
#  Start of Epoch Learning Rate = 0.098189
# Epoch 138/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 3.3226 - acc: 0.3997
#
#  End of Epoch Learning Rate = 0.097847
# 400/400 [==============================] - 105s 262ms/step - loss: 2.
254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 3.0663 - acc: 0.4389
#
#  End of Epoch Learning Rate = 0.092243
# 400/400 [==============================] - 105s 261ms/step - loss: 2.2441 - acc: 0.6179 - val_loss: 3.0663 - val_acc: 0.4389
#
#  Start of Epoch Learning Rate = 0.092243
# Epoch 150/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 2.9818 - acc: 0.4499
#
#  End of Epoch Learning Rate = 0.091574
# 400/400 [==============================] - 104s 261ms/step - loss: 2.2293 - acc: 0.6209 - val_loss: 2.9818 - val_acc: 0.4499
#
#  Start of Epoch Learning Rate = 0.091574
# Epoch 151/254
# 10000/10000 [==============================] - 6s 610us/sample - loss: 2.8032 - acc: 0.4852
#
#  End of Epoch Learning Rate = 0.090880
# 400/400 [==============================] - 105s 261ms/step - loss: 2.2148 - acc: 0.6240 - val_loss: 2.8032 - val_acc: 0.4852
#
#  Start of Epoch Learning Rate = 0.090880
# Epoch 152/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 3.0632 - acc: 0.4413
#
#  End of Epoch Learning Rate = 0.090161
# 400/400 [==============================] - 105s 262ms/step - loss: 2.2138 - acc: 0.6218 - val_loss: 3.0632 - val_acc: 0.4413
#
#  Start of Epoch Learning Rate = 0.090161
# Epoch 153/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 2.9710 - acc: 0.4615
#
#  End of Epoch Learning Rate = 0.089418
# ...
#
#  Start of Epoch Learning Rate = 0.034322
# Epoch 204/254
# 10000/10000 [==============================] - 6s 608us/sample - loss: 2.1816 - acc: 0.5893
#
#  End of Epoch Learning Rate = 0.033162
# 400/400 [==============================] - 104s 260ms/step - loss: 1.5486 - acc: 0.7417 - val_loss: 2.1816 - val_acc: 0.5893
#
#  Start of Epoch Learning Rate = 0.033162
# Epoch 205/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 2.0289 - acc: 0.6295
#
#  End of Epoch Learning Rate = 0.032012
# 400/400 [==============================] - 104s 261ms/step - loss: 1.5219 - acc: 0.7463 - val_loss: 2.0289 - val_acc: 0.6295
#
#  Start of Epoch Learning Rate = 0.032012
# Epoch 206/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 2.6317 - acc: 0.5014
#
#  End of Epoch Learning Rate = 0.030873
# 400/400 [==============================] - 105s 262ms/step - loss: 1.4962 - acc: 0.7526 - val_loss: 2.6317 - val_acc: 0.5014
#
#  Start of Epoch Learning Rate = 0.030873
# Epoch 207/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 2.0641 - acc: 0.6169
#
#  End of Epoch Learning Rate = 0.029745
# 400/400 [==============================] - 105s 262ms/step - loss: 1.4691 - acc: 0.7568 - val_loss: 2.0641 - val_acc: 0.6169
#
#  Start of Epoch Learning Rate = 0.029745
# Epoch 208/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 2.0607 - acc: 0.6164
#
#  End of Epoch Learning Rate = 0.028629
# 400/400 [==============================] - 105s 262ms/step - loss: 1.4628 - acc: 0.7602 - val_loss: 2.0607 - val_acc: 0.6164
#
#  Start of Epoch Learning Rate = 0.028629
# Epoch 209/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 1.9971 - acc: 0.6322
#
#  End of Epoch Learning Rate = 0.027527
# 400/400 [==============================] - 105s 262ms/step - loss: 1.4527 - acc: 0.7592 - val_loss: 1.9971 - val_acc: 0.6322
#
#  Start of Epoch Learning Rate = 0.027527
# Epoch 210/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 2.0006 - acc: 0.6235
#
#  End of Epoch Learning Rate = 0.026438
# 400/400 [==============================] - 105s 262ms/step - loss: 1.4177 - acc: 0.7670 - val_loss: 2.0006 - val_acc: 0.6235
#
#  Start of Epoch Learning Rate = 0.026438
# Epoch 211/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 1.9103 - acc: 0.6554
#
#  End of Epoch Learning Rate = 0.025363
# 400/400 [==============================] - 105s 262ms/step - loss: 1.3961 - acc: 0.7693 - val_loss: 1.9103 - val_acc: 0.6554
#
#  Start of Epoch Learning Rate = 0.025363
# Epoch 212/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 1.6968 - acc: 0.6809
#
#  End of Epoch Learning Rate = 0.024302
# 400/400 [==============================] - 105s 262ms/step - loss: 1.3799 - acc: 0.7745 - val_loss: 1.6968 - val_acc: 0.6809
#
#  Start of Epoch Learning Rate = 0.024302
# Epoch 213/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 2.2441 - acc: 0.5796
#
#  End of Epoch Learning Rate = 0.023258
# 400/400 [==============================] - 105s 262ms/step - loss: 1.3378 - acc: 0.7832 - val_loss: 2.2441 - val_acc: 0.5796
#
#  Start of Epoch Learning Rate = 0.023258
# Epoch 214/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 2.2618 - acc: 0.5716
#
#  End of Epoch Learning Rate = 0.022229
# 400/400 [==============================] - 105s 262ms/step - loss: 1.3258 - acc: 0.7865 - val_loss: 2.2618 - val_acc: 0.5716
#
#  Start of Epoch Learning Rate = 0.022229
# Epoch 215/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 1.8689 - acc: 0.6512
#
#  End of Epoch Learning Rate = 0.021217
# 400/400 [==============================] - 105s 262ms/step - loss: 1.3071 - acc: 0.7879 - val_loss: 1.8689 - val_acc: 0.6512
#
#  Start of Epoch Learning Rate = 0.021217
# Epoch 216/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 1.7723 - acc: 0.6632
#
#  End of Epoch Learning Rate = 0.020223
# 400/400 [==============================] - 105s 262ms/step - loss: 1.2819 - acc: 0.7954 - val_loss: 1.7723 - val_acc: 0.6632
#
#  Start of Epoch Learning Rate = 0.020223
# Epoch 217/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.8133 - acc: 0.6586
#
#  End of Epoch Learning Rate = 0.019246
# 400/400 [==============================] - 105s 262ms/step - loss: 1.2464 - acc: 0.8026 - val_loss: 1.8133 - val_acc: 0.6586
#
#  Start of Epoch Learning Rate = 0.019246
# Epoch 218/254
# 10000/10000 [==============================] - 6s 608us/sample - loss: 1.6940 - acc: 0.6847
#
#  End of Epoch Learning Rate = 0.018289
# 400/400 [==============================] - 105s 261ms/step - loss: 1.2377 - acc: 0.8048 - val_loss: 1.6940 - val_acc: 0.6847
#
#  Start of Epoch Learning Rate = 0.018289
# Epoch 219/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 1.8173 - acc: 0.6555
#
#  End of Epoch Learning Rate = 0.017350
# 400/400 [==============================] - 105s 261ms/step - loss: 1.2080 - acc: 0.8095 - val_loss: 1.8173 - val_acc: 0.6555
#
#  Start of Epoch Learning Rate = 0.017350
# Epoch 220/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 1.7834 - acc: 0.6622
#
#  End of Epoch Learning Rate = 0.016430
# 400/400 [==============================] - 105s 262ms/step - loss: 1.1772 - acc: 0.8168 - val_loss: 1.7834 - val_acc: 0.6622
#
#  Start of Epoch Learning Rate = 0.016430
# Epoch 221/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 1.7850 - acc: 0.6661
#
#  End of Epoch Learning Rate = 0.015531
# 400/400 [==============================] - 105s 262ms/step - loss: 1.1521 - acc: 0.8241 - val_loss: 1.7850 - val_acc: 0.6661
#
#  Start of Epoch Learning Rate = 0.015531
# Epoch 222/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 1.7927 - acc: 0.6562
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 105s 262ms/step - loss: 1.1209 - acc: 0.8301 - val_loss: 1.7927 - val_acc: 0.6562
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 223/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 1.6984 - acc: 0.6939
#
#  End of Epoch Learning Rate = 0.013796
# 400/400 [==============================] - 105s 262ms/step - loss: 1.0955 - acc: 0.8358 - val_loss: 1.6984 - val_acc: 0.6939
#
#  Start of Epoch Learning Rate = 0.013796
# Epoch 224/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 1.7385 - acc: 0.6797
#
#  End of Epoch Learning Rate = 0.012961
# 400/400 [==============================] - 105s 262ms/step - loss: 1.0773 - acc: 0.8399 - val_loss: 1.7385 - val_acc: 0.6797
#
#  Start of Epoch Learning Rate = 0.012961
# Epoch 225/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.6185 - acc: 0.7010
#
#  End of Epoch Learning Rate = 0.012148
# 400/400 [==============================] - 105s 262ms/step - loss: 1.0431 - acc: 0.8479 - val_loss: 1.6185 - val_acc: 0.7010
#
#  Start of Epoch Learning Rate = 0.012148
# Epoch 226/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 1.5533 - acc: 0.7080
#
#  End of Epoch Learning Rate = 0.011358
# 400/400 [==============================] - 105s 262ms/step - loss: 1.0239 - acc: 0.8516 - val_loss: 1.5533 - val_acc: 0.7080
#
#  Start of Epoch Learning Rate = 0.011358
# Epoch 227/254
# 10000/10000 [==============================] - 6s 625us/sample - loss: 1.6189 - acc: 0.7011
#
#  End of Epoch Learning Rate = 0.010592
# 400/400 [==============================] - 105s 262ms/step - loss: 0.9984 - acc: 0.8568 - val_loss: 1.6189 - val_acc: 0.7011
#
#  Start of Epoch Learning Rate = 0.010592
# Epoch 228/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 1.4941 - acc: 0.7196
#
#  End of Epoch Learning Rate = 0.009849
# 400/400 [==============================] - 105s 262ms/step - loss: 0.9647 - acc: 0.8660 - val_loss: 1.4941 - val_acc: 0.7196
#
#  Start of Epoch Learning Rate = 0.009849
# Epoch 229/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.5126 - acc: 0.7184
#
#  End of Epoch Learning Rate = 0.009130
# 400/400 [==============================] - 105s 262ms/step - loss: 0.9459 - acc: 0.8697 - val_loss: 1.5126 - val_acc: 0.7184
#
#  Start of Epoch Learning Rate = 0.009130
# Epoch 230/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 1.7287 - acc: 0.6767
#
#  End of Epoch Learning Rate = 0.008436
# 400/400 [==============================] - 105s 261ms/step - loss: 0.9159 - acc: 0.8761 - val_loss: 1.7287 - val_acc: 0.6767
#
#  Start of Epoch Learning Rate = 0.008436
# Epoch 231/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 1.4968 - acc: 0.7255
#
#  End of Epoch Learning Rate = 0.007767
# 400/400 [==============================] - 105s 262ms/step - loss: 0.8988 - acc: 0.8809 - val_loss: 1.4968 - val_acc: 0.7255
#
#  Start of Epoch Learning Rate = 0.007767
# Epoch 232/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.4422 - acc: 0.7330
#
#  End of Epoch Learning Rate = 0.007123
# 400/400 [==============================] - 105s 262ms/step - loss: 0.8640 - acc: 0.8901 - val_loss: 1.4422 - val_acc: 0.7330
#
#  Start of Epoch Learning Rate = 0.007123
# Epoch 233/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 1.4151 - acc: 0.7466
#
#  End of Epoch Learning Rate = 0.006505
# 400/400 [==============================] - 105s 262ms/step - loss: 0.8400 - acc: 0.8934 - val_loss: 1.4151 - val_acc: 0.7466
#
#  Start of Epoch Learning Rate = 0.006505
# Epoch 234/254
# 10000/10000 [==============================] - 6s 610us/sample - loss: 1.3617 - acc: 0.7541
#
#  End of Epoch Learning Rate = 0.005913
# 400/400 [==============================] - 105s 262ms/step - loss: 0.8175 - acc: 0.8997 - val_loss: 1.3617 - val_acc: 0.7541
#
#  Start of Epoch Learning Rate = 0.005913
# Epoch 235/254
# 10000/10000 [==============================] - 6s 609us/sample - loss: 1.3995 - acc: 0.7511
#
#  End of Epoch Learning Rate = 0.005348
# 400/400 [==============================] - 105s 262ms/step - loss: 0.7978 - acc: 0.9043 - val_loss: 1.3995 - val_acc: 0.7511
#
#  Start of Epoch Learning Rate = 0.005348
# Epoch 236/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 1.3239 - acc: 0.7594
#
#  End of Epoch Learning Rate = 0.004810
# 400/400 [==============================] - 105s 262ms/step - loss: 0.7757 - acc: 0.9087 - val_loss: 1.3239 - val_acc: 0.7594
#
#  Start of Epoch Learning Rate = 0.004810
# Epoch 237/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.3308 - acc: 0.7682
#
#  End of Epoch Learning Rate = 0.004299
# 400/400 [==============================] - 105s 262ms/step - loss: 0.7540 - acc: 0.9137 - val_loss: 1.3308 - val_acc: 0.7682
#
#  Start of Epoch Learning Rate = 0.004299
# Epoch 238/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.2336 - acc: 0.7785
#
#  End of Epoch Learning Rate = 0.003816
# 400/400 [==============================] - 105s 262ms/step - loss: 0.7343 - acc: 0.9195 - val_loss: 1.2336 - val_acc: 0.7785
#
#  Start of Epoch Learning Rate = 0.003816
# Epoch 239/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 1.3141 - acc: 0.7644
#
#  End of Epoch Learning Rate = 0.003360
# 400/400 [==============================] - 105s 262ms/step - loss: 0.7213 - acc: 0.9214 - val_loss: 1.3141 - val_acc: 0.7644
#
#  Start of Epoch Learning Rate = 0.003360
# Epoch 240/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 1.2633 - acc: 0.7809
#
#  End of Epoch Learning Rate = 0.002933
# 400/400 [==============================] - 105s 262ms/step - loss: 0.6927 - acc: 0.9305 - val_loss: 1.2633 - val_acc: 0.7809
#
#  Start of Epoch Learning Rate = 0.002933
# Epoch 241/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 1.1768 - acc: 0.7971
#
#  End of Epoch Learning Rate = 0.002533
# 400/400 [==============================] - 105s 262ms/step - loss: 0.6791 - acc: 0.9329 - val_loss: 1.1768 - val_acc: 0.7971
#
#  Start of Epoch Learning Rate = 0.002533
# Epoch 242/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 1.2172 - acc: 0.7877
#
#  End of Epoch Learning Rate = 0.002163
# 400/400 [==============================] - 105s 262ms/step - loss: 0.6646 - acc: 0.9355 - val_loss: 1.2172 - val_acc: 0.7877
#
#  Start of Epoch Learning Rate = 0.002163
# Epoch 243/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 1.2053 - acc: 0.7875
#
#  End of Epoch Learning Rate = 0.001821
# 400/400 [==============================] - 105s 261ms/step - loss: 0.6598 - acc: 0.9359 - val_loss: 1.2053 - val_acc: 0.7875
#
#  Start of Epoch Learning Rate = 0.001821
# Epoch 244/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.2084 - acc: 0.7985
#
#  End of Epoch Learning Rate = 0.001508
# 400/400 [==============================] - 105s 262ms/step - loss: 0.6390 - acc: 0.9421 - val_loss: 1.2084 - val_acc: 0.7985
#
#  Start of Epoch Learning Rate = 0.001508
# Epoch 245/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 1.1902 - acc: 0.7930
#
#  End of Epoch Learning Rate = 0.001225
# 400/400 [==============================] - 105s 262ms/step - loss: 0.6299 - acc: 0.9439 - val_loss: 1.1902 - val_acc: 0.7930
#
#  Start of Epoch Learning Rate = 0.001225
# Epoch 246/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 1.1732 - acc: 0.8024
#
#  End of Epoch Learning Rate = 0.000971
# 400/400 [==============================] - 105s 262ms/step - loss: 0.6176 - acc: 0.9472 - val_loss: 1.1732 - val_acc: 0.8024
#
#  Start of Epoch Learning Rate = 0.000971
# Epoch 247/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.1590 - acc: 0.8027
#
#  End of Epoch Learning Rate = 0.000746
# 400/400 [==============================] - 105s 262ms/step - loss: 0.6078 - acc: 0.9473 - val_loss: 1.1590 - val_acc: 0.8027
#
#  Start of Epoch Learning Rate = 0.000746
# Epoch 248/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.1331 - acc: 0.8091
#
#  End of Epoch Learning Rate = 0.000551
# 400/400 [==============================] - 105s 262ms/step - loss: 0.5962 - acc: 0.9521 - val_loss: 1.1331 - val_acc: 0.8091
#
#  Start of Epoch Learning Rate = 0.000551
# Epoch 249/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.1365 - acc: 0.8048
#
#  End of Epoch Learning Rate = 0.000386
# 400/400 [==============================] - 105s 262ms/step - loss: 0.5917 - acc: 0.9526 - val_loss: 1.1365 - val_acc: 0.8048
#
#  Start of Epoch Learning Rate = 0.000386
# Epoch 250/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 1.1270 - acc: 0.8077
#
#  End of Epoch Learning Rate = 0.000251
# 400/400 [==============================] - 105s 262ms/step - loss: 0.5824 - acc: 0.9539 - val_loss: 1.1270 - val_acc: 0.8077
#
#  Start of Epoch Learning Rate = 0.000251
# Epoch 251/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 1.1240 - acc: 0.8095
#
#  End of Epoch Learning Rate = 0.000145
# 400/400 [==============================] - 105s 262ms/step - loss: 0.5772 - acc: 0.9546 - val_loss: 1.1240 - val_acc: 0.8095
#
#  Start of Epoch Learning Rate = 0.000145
# Epoch 252/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.1263 - acc: 0.8115
#
#  End of Epoch Learning Rate = 0.000070
# 400/400 [==============================] - 105s 262ms/step - loss: 0.5779 - acc: 0.9555 - val_loss: 1.1263 - val_acc: 0.8115
#
#  Start of Epoch Learning Rate = 0.000070
# Epoch 253/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 1.1138 - acc: 0.8089
#
#  End of Epoch Learning Rate = 0.000025
# 400/400 [==============================] - 105s 262ms/step - loss: 0.5726 - acc: 0.9553 - val_loss: 1.1138 - val_acc: 0.8089
#
#  Start of Epoch Learning Rate = 0.000025
# Epoch 254/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 1.1149 - acc: 0.8118
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 105s 262ms/step - loss: 0.5778 - acc: 0.9547 - val_loss: 1.1149 - val_acc: 0.8118

# %%
#get final performance
y_pred = model.predict(x_test)
print('Test accuracy (%):', 100*sum(np.argmax(y_pred,-1)==np.argmax(y_test,-1))/y_test.shape[0])
# Out:
# Test accuracy (%): 81.18

# %% [markdown]
# For unknown reasons, likely related to bacth norm, this tensorflow.keras implementation falls short by 0.3% compared to the matlab version

# %%
#plot loss and accuracy
plot_history(model.history.history)

#plot learning rate schedule
plt.figure(figsize=(16,4))
plt.plot(np.arange(0,len(lr_scheduler.lr_used))/steps_per_epoch,lr_scheduler.lr_used)
plt.xlabel('epoch number')
plt.ylabel('learning rate')
plt.show()

# %%
#save the weigts used for updating
model.save_weights(ModelsPath+'Final_weights_'+WhichDataSet+'_full_precision.h5')

# %%
#create an inference model that uses regular conv2d layers
inference_model = resnet(UseBinaryWeights=False,input_shape=input_shape, depth=resnet_depth, num_classes=num_classes,wd=My_wd,width=resnet_width)
inference_model.compile(loss=Loss ,optimizer = Optimizer, metrics = Metrics)
inference_model.load_weights(ModelsPath+'Final_weights_'+WhichDataSet+'_full_precision.h5')

#get accuracy:
y_pred = inference_model.predict(x_test)
print('Test accuracy (%):', 100*sum(np.argmax(y_pred,-1)==np.argmax(y_test,-1))/y_test.shape[0])

#doesn't work yet because sign and scale not yet applied, as we set UseBinaryWeights=False for inference_model
# Out:
# Test accuracy (%): 1.0

# %%
#convert weights to one bit storage in python and copy into the inference model

ZeroOneWeightsDict = {}
AllParamsDict={}
NumBinaryWeights=0.0
for layer in inference_model.layers:
    #print(layer.name)

    if 'conv2d' in layer.name:
        ww=layer.get_weights()
        layer.set_weights(np.sign(ww)*np.sqrt(2.0/np.prod(ww[0].shape[0:3])))
        
        #storage using 1 bit booleans
        binary_weights = (0.5*(np.sign(ww)+1.0)).astype('bool')
        ZeroOneWeightsDict[layer.name]=binary_weights
        AllParamsDict[layer.name]=binary_weights
        NumBinaryWeights+=np.prod(ww[0].shape)
    elif 'batch_normalization' in layer.name:
        #the saved model also nees floating point batch norm params
        ww=layer.get_weights()
        AllParamsDict[layer.name]=ww
        
savemat(ModelsPath+WhichDataSet+'_01weights.mat',ZeroOneWeightsDict,do_compression=True,long_field_names=True)
savemat(ModelsPath+WhichDataSet+'_allparams.mat',AllParamsDict,do_compression=True,long_field_names=True)
inference_model.save_weights(ModelsPath+'Final_weights_'+WhichDataSet+'_binarized.h5')

WeightsMemory=NumBinaryWeights/8/1024/1024
print('Num binary weights = ',int(NumBinaryWeights),'; weights memory = ',WeightsMemory,'  MB')

#get accuracy:
y_pred = inference_model.predict(x_test)
print('Test accuracy (%):', 100*sum(np.argmax(y_pred,-1)==np.argmax(y_test,-1))/y_test.shape[0])
# Out:
# Num binary weights =  26794720 ; weights memory =  3.1941795349121094   MB
# Test accuracy (%): 81.18

# %%
#verify 1 bit weights work perfectly when loaded from h5 file

inference_model.load_weights(ModelsPath+'Final_weights_'+WhichDataSet+'_binarized.h5')

#verify each layer can take only two values:
cc=0
for layer in inference_model.layers:
    if 'conv2d' in layer.name:
        
        ww=layer.get_weights()
        uw = np.unique(ww)
        print('conv layer ',cc,' has ', len(uw),' unique weights')
        cc=cc+1

#get accuracy:
y_pred = inference_model.predict(x_test)
print('Test accuracy (%):', 100*sum(np.argmax(y_pred,-1)==np.argmax(y_test,-1))/y_test.shape[0])
# Out:
# conv layer  0  has  2  unique weights
# conv layer  1  has  2  unique weights
# conv layer  2  has  2  unique weights
# conv layer  3  has  2  unique weights
# conv layer  4  has  2  unique weights
# conv layer  5  has  2  unique weights
# conv layer  6  has  2  unique weights
# conv layer  7  has  2  unique weights
# conv layer  8  has  2  unique weights
# conv layer  9  has  2  unique weights
# conv layer  10  has  2  unique weights
# conv layer  11  has  2  unique weights
# conv layer  12  has  2  unique weights
# conv layer  13  has  2  unique weights
# conv layer  14  has  2  unique weights
# conv layer  15  has  2  unique weights
# conv layer  16  has  2  unique weights
# conv layer  17  has  2  unique weights
# conv layer  18  has  2  unique weights
# conv layer  19  has  2  unique weights
# Test accuracy (%): 81.18

# %%
#verify get the same results from compressed boolean storage
AllParamsDict_loaded=loadmat(ModelsPath+WhichDataSet+'_allparams.mat')


#verify each layer can take only two values:
#this requires layers saved with the same name as the most recently defined model
cc=0
for layer in inference_model.layers:
    if 'conv2d' in layer.name:
        ww=AllParamsDict_loaded[layer.name].astype('float32')*2.0-1.0
        ww=ww*np.sqrt(2.0/np.prod(ww[0].shape[0:3]))
        layer.set_weights([ww[0]])
        uw = np.unique(ww)
        print('conv layer ',cc,' has ', len(uw),' unique weights')
        cc=cc+1
    elif 'batch_normalization' in layer.name:
        #as a shortcut for this demo, note we already have the BN weights in the model
        #its a bit tedious wth .mat format to deal with the fact that BN layers can have a list of weights
        pass


#get accuracy:
y_pred = inference_model.predict(x_test)
print('Test accuracy (%):', 100*sum(np.argmax(y_pred,-1)==np.argmax(y_test,-1))/y_test.shape[0])
# Out:
# conv layer  0  has  2  unique weights
# conv layer  1  has  2  unique weights
# conv layer  2  has  2  unique weights
# conv layer  3  has  2  unique weights
# conv layer  4  has  2  unique weights
# conv layer  5  has  2  unique weights
# conv layer  6  has  2  unique weights
# conv layer  7  has  2  unique weights
# conv layer  8  has  2  unique weights
# conv layer  9  has  2  unique weights
# conv layer  10  has  2  unique weights
# conv layer  11  has  2  unique weights
# conv layer  12  has  2  unique weights
# conv layer  13  has  2  unique weights
# conv layer  14  has  2  unique weights
# conv layer  15  has  2  unique weights
# conv layer  16  has  2  unique weights
# conv layer  17  has  2  unique weights
# conv layer  18  has  2  unique weights
# conv layer  19  has  2  unique weights
# Test accuracy (%): 81.18

# %% [markdown]
# For unknown reasons, likely related to bacth norm, this tensorflow.keras implementation falls short by 0.3% compared to the matlab version
