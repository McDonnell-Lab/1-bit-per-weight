# %% [markdown]
# # Tensorflow.keras implementation of one-bit-per-weight CNN for CIFAR 100
# ##  https://arxiv.org/abs/1802.08530
# ## M. D. McDonnell,
# ## Training wide residual networks for deployment using a single bit for each weight
# ## ICLR, 2018

# %%
# select a GPU
import os
os.environ["CUDA_DEVICE_ORDER"] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = '5'

import numpy as np
import h5py
import matplotlib.pyplot as plt
import copy
from scipy.io import savemat,loadmat
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)

import tensorflow
print('Tensorflow version = ',tensorflow.__version__)
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import LearningRateScheduler, History

#from tensorflow.keras import backend as K

from ResNetModel import resnet
from Utils import cutout,LR_WarmRestart,GetDataGen,plot_history
# Out:
# Tensorflow version =  1.13.1

# %%
#params
#WhichDataSet = 'CIFAR10'
WhichDataSet = 'CIFAR100'
init_lr = 0.1
epochs = 254
batch_size = 125
My_wd=5e-4/2
resnet_width = 10
resnet_depth = 20
UseBinary=True
UseCutout=True
Loss = 'categorical_crossentropy'
Optimizer = SGD(lr=init_lr,decay=0.0, momentum=0.9, nesterov=False)
Metrics = ['accuracy']
ModelsPath = 'TrainedModels/Tensorflow.keras/'
# Out:
# WARNING:tensorflow:From /home/mdmcdonn/anaconda3/envs/April2019/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
#load and prepare data
if WhichDataSet == 'CIFAR10':
    (x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.cifar10.load_data()
else:
    (x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.cifar100.load_data()
num_classes = np.unique(y_train).shape[0]
K_train = x_train.shape[0]
input_shape = x_train.shape[1:]
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

# %%
#fdefine a datagen or generating training samples with flip and pad/crop augmentation, and if set to True, with cutout augmentation
dataGenerator = GetDataGen(UseCutout)

#define and compile the model
model = resnet(UseBinary,input_shape=input_shape, depth=resnet_depth, num_classes=num_classes,wd=My_wd,width=resnet_width)
model.compile(loss=Loss ,optimizer = Optimizer, metrics = Metrics)

#print  the model
model.summary()

#define the learnng rate schedule
steps_per_epoch = int(np.floor(K_train / batch_size))
lr_scheduler = LR_WarmRestart(nbatch=steps_per_epoch,
                              initial_lr=init_lr, min_lr=init_lr*1e-4,
                              epochs_restart = [1.0,3.0, 7.0, 15.0, 31.0, 63.0,127.0,255.0]) 

#define callbacks
history = History()
callbacks = [lr_scheduler,history]
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# batch_normalization_v1 (BatchNo (None, 32, 32, 3)    12          input_1[0][0]
# __________________________________________________________________________________________________
# binary_conv2d (BinaryConv2D)    (None, 32, 32, 160)  4320        batch_normalization_v1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_1 (Batch (None, 32, 32, 160)  320         binary_conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 160)  0           batch_normalization_v1_1[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_1 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_2 (Batch (None, 32, 32, 160)  320         binary_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_2[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_2 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 160)  0           binary_conv2d_2[0][0]
#                                                                  binary_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_3 (Batch (None, 32, 32, 160)  320         add[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_3[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_3 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_4 (Batch (None, 32, 32, 160)  320         binary_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_4[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_4 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 160)  0           binary_conv2d_4[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_5 (Batch (None, 32, 32, 160)  320         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_5[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_5 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_6 (Batch (None, 32, 32, 160)  320         binary_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_6[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_6 (BinaryConv2D)  (None, 32, 32, 160)  230400      activation_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 160)  0           binary_conv2d_6[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_7 (Batch (None, 32, 32, 160)  320         add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 160)  0           batch_normalization_v1_7[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_7 (BinaryConv2D)  (None, 16, 16, 320)  460800      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_8 (Batch (None, 16, 16, 320)  640         binary_conv2d_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 16, 16, 160)  0           add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 320)  0           batch_normalization_v1_8[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 16, 16, 160)  0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_8 (BinaryConv2D)  (None, 16, 16, 320)  921600      activation_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 320)  0           average_pooling2d[0][0]
#                                                                  lambda[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 320)  0           binary_conv2d_8[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_9 (Batch (None, 16, 16, 320)  640         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 320)  0           batch_normalization_v1_9[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_9 (BinaryConv2D)  (None, 16, 16, 320)  921600      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_10 (Batc (None, 16, 16, 320)  640         binary_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 320)  0           batch_normalization_v1_10[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_10 (BinaryConv2D) (None, 16, 16, 320)  921600      activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 320)  0           binary_conv2d_10[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_11 (Batc (None, 16, 16, 320)  640         add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 320)  0           batch_normalization_v1_11[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_11 (BinaryConv2D) (None, 16, 16, 320)  921600      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_12 (Batc (None, 16, 16, 320)  640         binary_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 320)  0           batch_normalization_v1_12[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_12 (BinaryConv2D) (None, 16, 16, 320)  921600      activation_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 320)  0           binary_conv2d_12[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_13 (Batc (None, 16, 16, 320)  640         add_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 320)  0           batch_normalization_v1_13[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_13 (BinaryConv2D) (None, 8, 8, 640)    1843200     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_14 (Batc (None, 8, 8, 640)    1280        binary_conv2d_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 8, 8, 320)    0           add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_14[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 8, 8, 320)    0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_14 (BinaryConv2D) (None, 8, 8, 640)    3686400     activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 640)    0           average_pooling2d_1[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 640)    0           binary_conv2d_14[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_15 (Batc (None, 8, 8, 640)    1280        add_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_15[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_15 (BinaryConv2D) (None, 8, 8, 640)    3686400     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_16 (Batc (None, 8, 8, 640)    1280        binary_conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_16[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_16 (BinaryConv2D) (None, 8, 8, 640)    3686400     activation_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 640)    0           binary_conv2d_16[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_17 (Batc (None, 8, 8, 640)    1280        add_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_17[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_17 (BinaryConv2D) (None, 8, 8, 640)    3686400     activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_18 (Batc (None, 8, 8, 640)    1280        binary_conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_18[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_18 (BinaryConv2D) (None, 8, 8, 640)    3686400     activation_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 640)    0           binary_conv2d_18[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_19 (Batc (None, 8, 8, 640)    1280        add_8[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 640)    0           batch_normalization_v1_19[0][0]
# __________________________________________________________________________________________________
# binary_conv2d_19 (BinaryConv2D) (None, 8, 8, 100)    64000       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_20 (Batc (None, 8, 8, 100)    200         binary_conv2d_19[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 100)          0           batch_normalization_v1_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 100)          0           global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 26,808,692
# Trainable params: 26,794,726
# Non-trainable params: 13,966
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(dataGenerator.flow(x_train, y_train, batch_size=batch_size),
                              validation_data=(x_test, y_test),
                              epochs=epochs,
                              verbose=1,
                              callbacks=callbacks,
                              steps_per_epoch =steps_per_epoch)
# Out:
# WARNING:tensorflow:From /home/mdmcdonn/anaconda3/envs/April2019/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 1/254
# 10000/10000 [==============================] - 7s 662us/sample - loss: 6.1754 - acc: 0.1786
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 110s 276ms/step - loss: 6.8013 - acc: 0.1383 - val_loss: 6.1754 - val_acc: 0.1786
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 2/254
# 10000/10000 [==============================] - 6s 634us/sample - loss: 5.2958 - acc: 0.3194
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 108s 270ms/step - loss: 5.6860 - acc: 0.2570 - val_loss: 5.2958 - val_acc: 0.3194
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 3/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 5.3281 - acc: 0.1982
#
#  End of Epoch Learning Rate = 0.085357
# 400/400 [==============================] - 108s 270ms/step - loss: 5.3018 - acc: 0.2555 - val_loss: 5.3281 - val_acc: 0.1982
#
#  Start of Epoch Learning Rate = 0.085357
# Epoch 4/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 4.1645 - acc: 0.3510
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 108s 270ms/step - loss: 4.3982 - acc: 0.3417 - val_loss: 4.1645 - val_acc: 0.3510
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 5/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 3.4834 - acc: 0.4659
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 107s 268ms/step - loss: 3.8094 - acc: 0.4209 - val_loss: 3.4834 - val_acc: 0.4659
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 6/254
# 10000/10000 [==============================] - 6s 641us/sample - loss: 3.0975 - acc: 0.5477
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 107s 268ms/step - loss: 3.4295 - acc: 0.4890 - val_loss: 3.0975 - val_acc: 0.5477
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 7/254
# 10000/10000 [==============================] - 6s 635us/sample - loss: 4.0541 - acc: 0.2952
#
#  End of Epoch Learning Rate = 0.096194
# 400/400 [==============================] - 107s 268ms/step - loss: 3.7623 - acc: 0.3934 - val_loss: 4.0541 - val_acc: 0.2952
#
#  Start of Epoch Learning Rate = 0.096194
# Epoch 8/254
# 10000/10000 [==============================] - 6s 625us/sample - loss: 3.7115 - acc: 0.3273
#
#  End of Epoch Learning Rate = 0.085357
# 400/400 [==============================] - 108s 269ms/step - loss: 3.3338 - acc: 0.4377 - val_loss: 3.7115 - val_acc: 0.3273
#
#  Start of Epoch Learning Rate = 0.085357
# Epoch 9/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 3.2868 - acc: 0.3901
#
#  End of Epoch Learning Rate = 0.069137
# 400/400 [==============================] - 107s 268ms/step - loss: 3.0127 - acc: 0.4809 - val_loss: 3.2868 - val_acc: 0.3901
#
#  Start of Epoch Learning Rate = 0.069137
# Epoch 10/254
# 10000/10000 [==============================] - 6s 622us/sample - loss: 2.8350 - acc: 0.4715
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 108s 269ms/step - loss: 2.7453 - acc: 0.5183 - val_loss: 2.8350 - val_acc: 0.4715
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 11/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 2.5842 - acc: 0.5269
#
#  End of Epoch Learning Rate = 0.030873
# 400/400 [==============================] - 107s 268ms/step - loss: 2.5046 - acc: 0.5572 - val_loss: 2.5842 - val_acc: 0.5269
#
#  Start of Epoch Learning Rate = 0.030873
# Epoch 12/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 2.1126 - acc: 0.6294
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 108s 269ms/step - loss: 2.2804 - acc: 0.6001 - val_loss: 2.1126 - val_acc: 0.6294
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 13/254
# 10000/10000 [==============================] - 6s 637us/sample - loss: 1.8936 - acc: 0.6673
#
#  End of Epoch Learning Rate = 0.003816
# 400/400 [==============================] - 107s 268ms/step - loss: 2.0726 - acc: 0.6440 - val_loss: 1.8936 - val_acc: 0.6673
#
#  Start of Epoch Learning Rate = 0.003816
# Epoch 14/254
# 10000/10000 [==============================] - 6s 631us/sample - loss: 1.7685 - acc: 0.6971
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 107s 268ms/step - loss: 1.9399 - acc: 0.6737 - val_loss: 1.7685 - val_acc: 0.6971
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 15/254
# 10000/10000 [==============================] - 6s 622us/sample - loss: 3.1937 - acc: 0.3785
#
#  End of Epoch Learning Rate = 0.099039
# 400/400 [==============================] - 107s 268ms/step - loss: 2.7006 - acc: 0.5021 - val_loss: 3.1937 - val_acc: 0.3785
#
#  Start of Epoch Learning Rate = 0.099039
# Epoch 16/254
# 10000/10000 [==============================] - 6s 625us/sample - loss: 3.2840 - acc: 0.3616
#
#  End of Epoch Learning Rate = 0.096194
# 400/400 [==============================] - 107s 268ms/step - loss: 2.5896 - acc: 0.5213 - val_loss: 3.2840 - val_acc: 0.3616
#
#  Start of Epoch Learning Rate = 0.096194
# Epoch 17/254
# 10000/10000 [==============================] - 6s 624us/sample - loss: 2.9808 - acc: 0.4294
#
#  End of Epoch Learning Rate = 0.091574
# 400/400 [==============================] - 107s 268ms/step - loss: 2.5043 - acc: 0.5389 - val_loss: 2.9808 - val_acc: 0.4294
#
#  Start of Epoch Learning Rate = 0.091574
# Epoch 18/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 3.1711 - acc: 0.3920
#
#  End of Epoch Learning Rate = 0.085357
# 400/400 [==============================] - 107s 267ms/step - loss: 2.4293 - acc: 0.5509 - val_loss: 3.1711 - val_acc: 0.3920
#
#  Start of Epoch Learning Rate = 0.085357
# Epoch 19/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 2.8845 - acc: 0.4324
#
#  End of Epoch Learning Rate = 0.077781
# 400/400 [==============================] - 107s 267ms/step - loss: 2.3485 - acc: 0.5651 - val_loss: 2.8845 - val_acc: 0.4324
#
#  Start of Epoch Learning Rate = 0.077781
# Epoch 20/254
# 10000/10000 [==============================] - 6s 639us/sample - loss: 3.0664 - acc: 0.4098
#
#  End of Epoch Learning Rate = 0.069137
# 400/400 [==============================] - 107s 268ms/step - loss: 2.2785 - acc: 0.5785 - val_loss: 3.0664 - val_acc: 0.4098
#
#  Start of Epoch Learning Rate = 0.069137
# Epoch 21/254
# 10000/10000 [==============================] - 6s 627us/sample - loss: 2.5504 - acc: 0.5041
#
#  End of Epoch Learning Rate = 0.059759
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1836 - acc: 0.5954 - val_loss: 2.5504 - val_acc: 0.5041
#
#  Start of Epoch Learning Rate = 0.059759
# Epoch 22/254
# 10000/10000 [==============================] - 6s 622us/sample - loss: 2.1578 - acc: 0.5875
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 107s 268ms/step - loss: 2.0971 - acc: 0.6121 - val_loss: 2.1578 - val_acc: 0.5875
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 23/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 2.2013 - acc: 0.5796
#
#  End of Epoch Learning Rate = 0.040251
# 400/400 [==============================] - 107s 268ms/step - loss: 1.9793 - acc: 0.6370 - val_loss: 2.2013 - val_acc: 0.5796
#
#  Start of Epoch Learning Rate = 0.040251
# Epoch 24/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 2.1073 - acc: 0.5990
#
#  End of Epoch Learning Rate = 0.030873
# 400/400 [==============================] - 107s 268ms/step - loss: 1.8739 - acc: 0.6578 - val_loss: 2.1073 - val_acc: 0.5990
#
#  Start of Epoch Learning Rate = 0.030873
# Epoch 25/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 1.9860 - acc: 0.6219
#
#  End of Epoch Learning Rate = 0.022229
# 400/400 [==============================] - 107s 268ms/step - loss: 1.7563 - acc: 0.6824 - val_loss: 1.9860 - val_acc: 0.6219
#
#  Start of Epoch Learning Rate = 0.022229
# Epoch 26/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.7742 - acc: 0.6688
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 107s 268ms/step - loss: 1.6286 - acc: 0.7115 - val_loss: 1.7742 - val_acc: 0.6688
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 27/254
# 10000/10000 [==============================] - 6s 632us/sample - loss: 1.5220 - acc: 0.7198
#
#  End of Epoch Learning Rate = 0.008436
# 400/400 [==============================] - 108s 269ms/step - loss: 1.5004 - acc: 0.7386 - val_loss: 1.5220 - val_acc: 0.7198
#
#  Start of Epoch Learning Rate = 0.008436
# Epoch 28/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 1.4225 - acc: 0.7405
#
#  End of Epoch Learning Rate = 0.003816
# 400/400 [==============================] - 107s 268ms/step - loss: 1.3859 - acc: 0.7656 - val_loss: 1.4225 - val_acc: 0.7405
#
#  Start of Epoch Learning Rate = 0.003816
# Epoch 29/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 1.3112 - acc: 0.7633
#
#  End of Epoch Learning Rate = 0.000971
# 400/400 [==============================] - 107s 268ms/step - loss: 1.2908 - acc: 0.7906 - val_loss: 1.3112 - val_acc: 0.7633
#
#  Start of Epoch Learning Rate = 0.000971
# Epoch 30/254
# 10000/10000 [==============================] - 6s 624us/sample - loss: 1.2920 - acc: 0.7658
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 107s 267ms/step - loss: 1.2466 - acc: 0.8022 - val_loss: 1.2920 - val_acc: 0.7658
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 31/254
# 10000/10000 [==============================] - 6s 630us/sample - loss: 3.0982 - acc: 0.3938
#
#  End of Epoch Learning Rate = 0.099759
# 400/400 [==============================] - 107s 268ms/step - loss: 2.3477 - acc: 0.5477 - val_loss: 3.0982 - val_acc: 0.3938
#
#  Start of Epoch Learning Rate = 0.099759
# Epoch 32/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 3.5261 - acc: 0.3113
#
#  End of Epoch Learning Rate = 0.099039
# 400/400 [==============================] - 107s 268ms/step - loss: 2.3247 - acc: 0.5651 - val_loss: 3.5261 - val_acc: 0.3113
#
#  Start of Epoch Learning Rate = 0.099039
# Epoch 33/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 3.1194 - acc: 0.3890
#
#  End of Epoch Learning Rate = 0.097847
# 400/400 [==============================] - 107s 267ms/step - loss: 2.3211 - acc: 0.5690 - val_loss: 3.1194 - val_acc: 0.3890
#
#  Start of Epoch Learning Rate = 0.097847
# Epoch 34/254
# 10000/10000 [==============================] - 6s 635us/sample - loss: 2.9226 - acc: 0.4455
#
#  End of Epoch Learning Rate = 0.096194
# 400/400 [==============================] - 107s 267ms/step - loss: 2.2975 - acc: 0.5771 - val_loss: 2.9226 - val_acc: 0.4455
#
#  Start of Epoch Learning Rate = 0.096194
# Epoch 35/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 3.0331 - acc: 0.4074
#
#  End of Epoch Learning Rate = 0.094097
# 400/400 [==============================] - 107s 267ms/step - loss: 2.2953 - acc: 0.5790 - val_loss: 3.0331 - val_acc: 0.4074
#
#  Start of Epoch Learning Rate = 0.094097
# Epoch 36/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 2.9391 - acc: 0.4413
#
#  End of Epoch Learning Rate = 0.091574
# 400/400 [==============================] - 107s 268ms/step - loss: 2.2696 - acc: 0.5880 - val_loss: 2.9391 - val_acc: 0.4413
#
#  Start of Epoch Learning Rate = 0.091574
# Epoch 37/254
# 10000/10000 [==============================] - 6s 630us/sample - loss: 3.0562 - acc: 0.4174
#
#  End of Epoch Learning Rate = 0.088652
# 400/400 [==============================] - 108s 269ms/step - loss: 2.2489 - acc: 0.5914 - val_loss: 3.0562 - val_acc: 0.4174
#
#  Start of Epoch Learning Rate = 0.088652
# Epoch 38/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 3.2350 - acc: 0.3776
#
#  End of Epoch Learning Rate = 0.085357
# 400/400 [==============================] - 107s 268ms/step - loss: 2.2156 - acc: 0.5978 - val_loss: 3.2350 - val_acc: 0.3776
#
#  Start of Epoch Learning Rate = 0.085357
# Epoch 39/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 3.0558 - acc: 0.4051
#
#  End of Epoch Learning Rate = 0.081721
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1869 - acc: 0.6066 - val_loss: 3.0558 - val_acc: 0.4051
#
#  Start of Epoch Learning Rate = 0.081721
# Epoch 40/254
# 10000/10000 [==============================] - 6s 625us/sample - loss: 2.8212 - acc: 0.4428
#
#  End of Epoch Learning Rate = 0.077781
# 400/400 [==============================] - 107s 269ms/step - loss: 2.1558 - acc: 0.6125 - val_loss: 2.8212 - val_acc: 0.4428
#
#  Start of Epoch Learning Rate = 0.077781
# Epoch 41/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 2.8418 - acc: 0.4615
#
#  End of Epoch Learning Rate = 0.073572
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1231 - acc: 0.6186 - val_loss: 2.8418 - val_acc: 0.4615
#
#  Start of Epoch Learning Rate = 0.073572
# Epoch 42/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 2.7352 - acc: 0.4710
#
#  End of Epoch Learning Rate = 0.069137
# 400/400 [==============================] - 107s 266ms/step - loss: 2.0899 - acc: 0.6242 - val_loss: 2.7352 - val_acc: 0.4710
#
#  Start of Epoch Learning Rate = 0.069137
# Epoch 43/254
# 10000/10000 [==============================] - 6s 632us/sample - loss: 2.6976 - acc: 0.4794
#
#  End of Epoch Learning Rate = 0.064518
# 400/400 [==============================] - 107s 268ms/step - loss: 2.0478 - acc: 0.6330 - val_loss: 2.6976 - val_acc: 0.4794
#
#  Start of Epoch Learning Rate = 0.064518
# Epoch 44/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 2.3710 - acc: 0.5552
#
#  End of Epoch Learning Rate = 0.059759
# 400/400 [==============================] - 107s 268ms/step - loss: 2.0011 - acc: 0.6445 - val_loss: 2.3710 - val_acc: 0.5552
#
#  Start of Epoch Learning Rate = 0.059759
# Epoch 45/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 2.2175 - acc: 0.5829
#
#  End of Epoch Learning Rate = 0.054905
# 400/400 [==============================] - 107s 268ms/step - loss: 1.9469 - acc: 0.6536 - val_loss: 2.2175 - val_acc: 0.5829
#
#  Start of Epoch Learning Rate = 0.054905
# Epoch 46/254
# 10000/10000 [==============================] - 6s 635us/sample - loss: 2.3038 - acc: 0.5598
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 107s 268ms/step - loss: 1.8970 - acc: 0.6615 - val_loss: 2.3038 - val_acc: 0.5598
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 47/254
# 10000/10000 [==============================] - 6s 632us/sample - loss: 2.0497 - acc: 0.6051
#
#  End of Epoch Learning Rate = 0.045105
# 400/400 [==============================] - 107s 268ms/step - loss: 1.8405 - acc: 0.6738 - val_loss: 2.0497 - val_acc: 0.6051
#
#  Start of Epoch Learning Rate = 0.045105
# Epoch 48/254
# 10000/10000 [==============================] - 6s 627us/sample - loss: 2.1149 - acc: 0.5877
#
#  End of Epoch Learning Rate = 0.040251
# 400/400 [==============================] - 107s 267ms/step - loss: 1.7840 - acc: 0.6856 - val_loss: 2.1149 - val_acc: 0.5877
#
#  Start of Epoch Learning Rate = 0.040251
# Epoch 49/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 2.1042 - acc: 0.5971
#
#  End of Epoch Learning Rate = 0.035492
# 400/400 [==============================] - 107s 268ms/step - loss: 1.7197 - acc: 0.6967 - val_loss: 2.1042 - val_acc: 0.5971
#
#  Start of Epoch Learning Rate = 0.035492
# Epoch 50/254
# 10000/10000 [==============================] - 6s 624us/sample - loss: 1.9645 - acc: 0.6277
#
#  End of Epoch Learning Rate = 0.030873
# 400/400 [==============================] - 108s 270ms/step - loss: 1.6498 - acc: 0.7096 - val_loss: 1.9645 - val_acc: 0.6277
#
#  Start of Epoch Learning Rate = 0.030873
# Epoch 51/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 1.9392 - acc: 0.6301
#
#  End of Epoch Learning Rate = 0.026438
# 400/400 [==============================] - 107s 268ms/step - loss: 1.5841 - acc: 0.7244 - val_loss: 1.9392 - val_acc: 0.6301
#
#  Start of Epoch Learning Rate = 0.026438
# Epoch 52/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 1.8565 - acc: 0.6470
#
#  End of Epoch Learning Rate = 0.022229
# 400/400 [==============================] - 107s 267ms/step - loss: 1.5105 - acc: 0.7410 - val_loss: 1.8565 - val_acc: 0.6470
#
#  Start of Epoch Learning Rate = 0.022229
# Epoch 53/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.6855 - acc: 0.6853
#
#  End of Epoch Learning Rate = 0.018289
# 400/400 [==============================] - 107s 268ms/step - loss: 1.4396 - acc: 0.7554 - val_loss: 1.6855 - val_acc: 0.6853
#
#  Start of Epoch Learning Rate = 0.018289
# Epoch 54/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 1.5489 - acc: 0.7122
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 107s 267ms/step - loss: 1.3600 - acc: 0.7723 - val_loss: 1.5489 - val_acc: 0.7122
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 55/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.5644 - acc: 0.7094
#
#  End of Epoch Learning Rate = 0.011358
# 400/400 [==============================] - 107s 268ms/step - loss: 1.2810 - acc: 0.7931 - val_loss: 1.5644 - val_acc: 0.7094
#
#  Start of Epoch Learning Rate = 0.011358
# Epoch 56/254
# 10000/10000 [==============================] - 6s 622us/sample - loss: 1.4349 - acc: 0.7370
#
#  End of Epoch Learning Rate = 0.008436
# 400/400 [==============================] - 107s 267ms/step - loss: 1.1998 - acc: 0.8146 - val_loss: 1.4349 - val_acc: 0.7370
#
#  Start of Epoch Learning Rate = 0.008436
# Epoch 57/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 1.3315 - acc: 0.7588
#
#  End of Epoch Learning Rate = 0.005913
# 400/400 [==============================] - 107s 269ms/step - loss: 1.1283 - acc: 0.8296 - val_loss: 1.3315 - val_acc: 0.7588
#
#  Start of Epoch Learning Rate = 0.005913
# Epoch 58/254
# 10000/10000 [==============================] - 6s 636us/sample - loss: 1.3416 - acc: 0.7636
#
#  End of Epoch Learning Rate = 0.003816
# 400/400 [==============================] - 107s 268ms/step - loss: 1.0646 - acc: 0.8453 - val_loss: 1.3416 - val_acc: 0.7636
#
#  Start of Epoch Learning Rate = 0.003816
# Epoch 59/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 1.2131 - acc: 0.7857
#
#  End of Epoch Learning Rate = 0.002163
# 400/400 [==============================] - 107s 268ms/step - loss: 1.0048 - acc: 0.8635 - val_loss: 1.2131 - val_acc: 0.7857
#
#  Start of Epoch Learning Rate = 0.002163
# Epoch 60/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.1910 - acc: 0.7970
#
#  End of Epoch Learning Rate = 0.000971
# 400/400 [==============================] - 107s 267ms/step - loss: 0.9694 - acc: 0.8724 - val_loss: 1.1910 - val_acc: 0.7970
#
#  Start of Epoch Learning Rate = 0.000971
# Epoch 61/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 1.1691 - acc: 0.7999
#
#  End of Epoch Learning Rate = 0.000251
# 400/400 [==============================] - 107s 268ms/step - loss: 0.9336 - acc: 0.8821 - val_loss: 1.1691 - val_acc: 0.7999
#
#  Start of Epoch Learning Rate = 0.000251
# Epoch 62/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.1633 - acc: 0.8012
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 107s 267ms/step - loss: 0.9159 - acc: 0.8859 - val_loss: 1.1633 - val_acc: 0.8012
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 63/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 3.0353 - acc: 0.4195
#
#  End of Epoch Learning Rate = 0.099940
# 400/400 [==============================] - 107s 267ms/step - loss: 2.2877 - acc: 0.5618 - val_loss: 3.0353 - val_acc: 0.4195
#
#  Start of Epoch Learning Rate = 0.099940
# Epoch 64/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 3.4944 - acc: 0.3292
#
#  End of Epoch Learning Rate = 0.099759
# 400/400 [==============================] - 107s 268ms/step - loss: 2.2495 - acc: 0.5849 - val_loss: 3.4944 - val_acc: 0.3292
#
#  Start of Epoch Learning Rate = 0.099759
# Epoch 65/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 3.1995 - acc: 0.4046
#
#  End of Epoch Learning Rate = 0.099459
# 400/400 [==============================] - 107s 267ms/step - loss: 2.2439 - acc: 0.5926 - val_loss: 3.1995 - val_acc: 0.4046
#
#  Start of Epoch Learning Rate = 0.099459
# Epoch 66/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 3.2570 - acc: 0.3695
#
#  End of Epoch Learning Rate = 0.099039
# 400/400 [==============================] - 107s 267ms/step - loss: 2.2321 - acc: 0.5991 - val_loss: 3.2570 - val_acc: 0.3695
#
#  Start of Epoch Learning Rate = 0.099039
# Epoch 67/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 3.1452 - acc: 0.4041
#
#  End of Epoch Learning Rate = 0.098502
# 400/400 [==============================] - 107s 268ms/step - loss: 2.2358 - acc: 0.6025 - val_loss: 3.1452 - val_acc: 0.4041
#
#  Start of Epoch Learning Rate = 0.098502
# Epoch 68/254
# 10000/10000 [==============================] - 6s 622us/sample - loss: 3.0130 - acc: 0.4334
#
#  End of Epoch Learning Rate = 0.097847
# 400/400 [==============================] - 107s 267ms/step - loss: 2.2374 - acc: 0.6041 - val_loss: 3.0130 - val_acc: 0.4334
#
#  Start of Epoch Learning Rate = 0.097847
# Epoch 69/254
# 10000/10000 [==============================] - 6s 631us/sample - loss: 2.8762 - acc: 0.4677
#
#  End of Epoch Learning Rate = 0.097077
# 400/400 [==============================] - 107s 267ms/step - loss: 2.2233 - acc: 0.6108 - val_loss: 2.8762 - val_acc: 0.4677
#
#  Start of Epoch Learning Rate = 0.097077
# Epoch 70/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 3.2537 - acc: 0.3836
#
#  End of Epoch Learning Rate = 0.096194
# 400/400 [==============================] - 107s 268ms/step - loss: 2.2282 - acc: 0.6105 - val_loss: 3.2537 - val_acc: 0.3836
#
#  Start of Epoch Learning Rate = 0.096194
# Epoch 71/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 2.9182 - acc: 0.4511
#
#  End of Epoch Learning Rate = 0.095200
# 400/400 [==============================] - 107s 267ms/step - loss: 2.2194 - acc: 0.6127 - val_loss: 2.9182 - val_acc: 0.4511
#
#  Start of Epoch Learning Rate = 0.095200
# Epoch 72/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 2.7856 - acc: 0.4885
#
#  End of Epoch Learning Rate = 0.094097
# 400/400 [==============================] - 107s 267ms/step - loss: 2.2119 - acc: 0.6148 - val_loss: 2.7856 - val_acc: 0.4885
#
#  Start of Epoch Learning Rate = 0.094097
# Epoch 73/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 2.8914 - acc: 0.4635
#
#  End of Epoch Learning Rate = 0.092887
# 400/400 [==============================] - 107s 269ms/step - loss: 2.2046 - acc: 0.6170 - val_loss: 2.8914 - val_acc: 0.4635
#
#  Start of Epoch Learning Rate = 0.092887
# Epoch 74/254
# 10000/10000 [==============================] - 6s 627us/sample - loss: 2.9026 - acc: 0.4395
#
#  End of Epoch Learning Rate = 0.091574
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1809 - acc: 0.6219 - val_loss: 2.9026 - val_acc: 0.4395
#
#  Start of Epoch Learning Rate = 0.091574
# Epoch 75/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 2.7474 - acc: 0.4888
#
#  End of Epoch Learning Rate = 0.090161
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1832 - acc: 0.6213 - val_loss: 2.7474 - val_acc: 0.4888
#
#  Start of Epoch Learning Rate = 0.090161
# Epoch 76/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 3.0107 - acc: 0.4409
#
#  End of Epoch Learning Rate = 0.088652
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1640 - acc: 0.6239 - val_loss: 3.0107 - val_acc: 0.4409
#
#  Start of Epoch Learning Rate = 0.088652
# Epoch 77/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 3.1251 - acc: 0.4237
#
#  End of Epoch Learning Rate = 0.087049
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1546 - acc: 0.6268 - val_loss: 3.1251 - val_acc: 0.4237
#
#  Start of Epoch Learning Rate = 0.087049
# Epoch 78/254
# 10000/10000 [==============================] - 6s 630us/sample - loss: 2.8568 - acc: 0.4808
#
#  End of Epoch Learning Rate = 0.085357
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1472 - acc: 0.6270 - val_loss: 2.8568 - val_acc: 0.4808
#
#  Start of Epoch Learning Rate = 0.085357
# Epoch 79/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 3.2626 - acc: 0.3877
#
#  End of Epoch Learning Rate = 0.083580
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1174 - acc: 0.6335 - val_loss: 3.2626 - val_acc: 0.3877
#
#  Start of Epoch Learning Rate = 0.083580
# Epoch 80/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 2.5229 - acc: 0.5262
#
#  End of Epoch Learning Rate = 0.081721
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1003 - acc: 0.6364 - val_loss: 2.5229 - val_acc: 0.5262
#
#  Start of Epoch Learning Rate = 0.081721
# Epoch 81/254
# 10000/10000 [==============================] - 6s 625us/sample - loss: 3.1748 - acc: 0.3998
#
#  End of Epoch Learning Rate = 0.079787
# 400/400 [==============================] - 107s 267ms/step - loss: 2.0906 - acc: 0.6392 - val_loss: 3.1748 - val_acc: 0.3998
#
#  Start of Epoch Learning Rate = 0.079787
# Epoch 82/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 2.8664 - acc: 0.4578
#
#  End of Epoch Learning Rate = 0.077781
# 400/400 [==============================] - 107s 267ms/step - loss: 2.0768 - acc: 0.6408 - val_loss: 2.8664 - val_acc: 0.4578
#
#  Start of Epoch Learning Rate = 0.077781
# Epoch 83/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 3.1281 - acc: 0.4070
#
#  End of Epoch Learning Rate = 0.075708
# 400/400 [==============================] - 107s 267ms/step - loss: 2.0584 - acc: 0.6435 - val_loss: 3.1281 - val_acc: 0.4070
#
#  Start of Epoch Learning Rate = 0.075708
# Epoch 84/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 2.7148 - acc: 0.5011
#
#  End of Epoch Learning Rate = 0.073572
# 400/400 [==============================] - 107s 266ms/step - loss: 2.0401 - acc: 0.6449 - val_loss: 2.7148 - val_acc: 0.5011
#
#  Start of Epoch Learning Rate = 0.073572
# Epoch 85/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 2.6396 - acc: 0.5029
#
#  End of Epoch Learning Rate = 0.071381
# 400/400 [==============================] - 107s 267ms/step - loss: 2.0099 - acc: 0.6524 - val_loss: 2.6396 - val_acc: 0.5029
#
#  Start of Epoch Learning Rate = 0.071381
# Epoch 86/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 3.1366 - acc: 0.4189
#
#  End of Epoch Learning Rate = 0.069137
# 400/400 [==============================] - 107s 267ms/step - loss: 1.9884 - acc: 0.6550 - val_loss: 3.1366 - val_acc: 0.4189
#
#  Start of Epoch Learning Rate = 0.069137
# Epoch 87/254
# 10000/10000 [==============================] - 6s 622us/sample - loss: 2.8606 - acc: 0.4657
#
#  End of Epoch Learning Rate = 0.066848
# 400/400 [==============================] - 107s 268ms/step - loss: 1.9616 - acc: 0.6634 - val_loss: 2.8606 - val_acc: 0.4657
#
#  Start of Epoch Learning Rate = 0.066848
# Epoch 88/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 2.5160 - acc: 0.5264
#
#  End of Epoch Learning Rate = 0.064518
# 400/400 [==============================] - 107s 268ms/step - loss: 1.9457 - acc: 0.6646 - val_loss: 2.5160 - val_acc: 0.5264
#
#  Start of Epoch Learning Rate = 0.064518
# Epoch 89/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 2.9897 - acc: 0.4416
#
#  End of Epoch Learning Rate = 0.062153
# 400/400 [==============================] - 107s 267ms/step - loss: 1.9227 - acc: 0.6680 - val_loss: 2.9897 - val_acc: 0.4416
#
#  Start of Epoch Learning Rate = 0.062153
# Epoch 90/254
# 10000/10000 [==============================] - 6s 622us/sample - loss: 2.5388 - acc: 0.5196
#
#  End of Epoch Learning Rate = 0.059759
# 400/400 [==============================] - 107s 267ms/step - loss: 1.8953 - acc: 0.6711 - val_loss: 2.5388 - val_acc: 0.5196
#
#  Start of Epoch Learning Rate = 0.059759
# Epoch 91/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 2.4026 - acc: 0.5425
#
#  End of Epoch Learning Rate = 0.057341
# 400/400 [==============================] - 107s 268ms/step - loss: 1.8732 - acc: 0.6761 - val_loss: 2.4026 - val_acc: 0.5425
#
#  Start of Epoch Learning Rate = 0.057341
# Epoch 92/254
# 10000/10000 [==============================] - 6s 627us/sample - loss: 2.5646 - acc: 0.5433
#
#  End of Epoch Learning Rate = 0.054905
# 400/400 [==============================] - 107s 267ms/step - loss: 1.8469 - acc: 0.6810 - val_loss: 2.5646 - val_acc: 0.5433
#
#  Start of Epoch Learning Rate = 0.054905
# Epoch 93/254
# 10000/10000 [==============================] - 6s 636us/sample - loss: 2.4713 - acc: 0.5219
#
#  End of Epoch Learning Rate = 0.052458
# 400/400 [==============================] - 107s 268ms/step - loss: 1.8137 - acc: 0.6847 - val_loss: 2.4713 - val_acc: 0.5219
#
#  Start of Epoch Learning Rate = 0.052458
# Epoch 94/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 2.4020 - acc: 0.5483
#
#  End of Epoch Learning Rate = 0.050005
# 400/400 [==============================] - 107s 267ms/step - loss: 1.7843 - acc: 0.6922 - val_loss: 2.4020 - val_acc: 0.5483
#
#  Start of Epoch Learning Rate = 0.050005
# Epoch 95/254
# 10000/10000 [==============================] - 6s 635us/sample - loss: 2.4548 - acc: 0.5326
#
#  End of Epoch Learning Rate = 0.047552
# 400/400 [==============================] - 107s 267ms/step - loss: 1.7612 - acc: 0.6946 - val_loss: 2.4548 - val_acc: 0.5326
#
#  Start of Epoch Learning Rate = 0.047552
# Epoch 96/254
# 10000/10000 [==============================] - 6s 627us/sample - loss: 2.0986 - acc: 0.6103
#
#  End of Epoch Learning Rate = 0.045105
# 400/400 [==============================] - 107s 268ms/step - loss: 1.7252 - acc: 0.7035 - val_loss: 2.0986 - val_acc: 0.6103
#
#  Start of Epoch Learning Rate = 0.045105
# Epoch 97/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 2.1795 - acc: 0.5964
#
#  End of Epoch Learning Rate = 0.042669
# 400/400 [==============================] - 107s 267ms/step - loss: 1.6890 - acc: 0.7102 - val_loss: 2.1795 - val_acc: 0.5964
#
#  Start of Epoch Learning Rate = 0.042669
# Epoch 98/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 2.0721 - acc: 0.6059
#
#  End of Epoch Learning Rate = 0.040251
# 400/400 [==============================] - 107s 267ms/step - loss: 1.6561 - acc: 0.7154 - val_loss: 2.0721 - val_acc: 0.6059
#
#  Start of Epoch Learning Rate = 0.040251
# Epoch 99/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 2.1152 - acc: 0.6026
#
#  End of Epoch Learning Rate = 0.037857
# 400/400 [==============================] - 107s 267ms/step - loss: 1.6253 - acc: 0.7205 - val_loss: 2.1152 - val_acc: 0.6026
#
#  Start of Epoch Learning Rate = 0.037857
# Epoch 100/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 2.1963 - acc: 0.5799
#
#  End of Epoch Learning Rate = 0.035492
# 400/400 [==============================] - 107s 267ms/step - loss: 1.5878 - acc: 0.7298 - val_loss: 2.1963 - val_acc: 0.5799
#
#  Start of Epoch Learning Rate = 0.035492
# Epoch 101/254
# 10000/10000 [==============================] - 6s 625us/sample - loss: 2.0415 - acc: 0.6234
#
#  End of Epoch Learning Rate = 0.033162
# 400/400 [==============================] - 107s 268ms/step - loss: 1.5502 - acc: 0.7350 - val_loss: 2.0415 - val_acc: 0.6234
#
#  Start of Epoch Learning Rate = 0.033162
# Epoch 102/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 2.3191 - acc: 0.5633
#
#  End of Epoch Learning Rate = 0.030873
# 400/400 [==============================] - 107s 267ms/step - loss: 1.5204 - acc: 0.7424 - val_loss: 2.3191 - val_acc: 0.5633
#
#  Start of Epoch Learning Rate = 0.030873
# Epoch 103/254
# 10000/10000 [==============================] - 6s 632us/sample - loss: 2.0692 - acc: 0.6112
#
#  End of Epoch Learning Rate = 0.028629
# 400/400 [==============================] - 107s 268ms/step - loss: 1.4785 - acc: 0.7508 - val_loss: 2.0692 - val_acc: 0.6112
#
#  Start of Epoch Learning Rate = 0.028629
# Epoch 104/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.8471 - acc: 0.6574
#
#  End of Epoch Learning Rate = 0.026438
# 400/400 [==============================] - 107s 268ms/step - loss: 1.4362 - acc: 0.7598 - val_loss: 1.8471 - val_acc: 0.6574
#
#  Start of Epoch Learning Rate = 0.026438
# Epoch 105/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 1.8779 - acc: 0.6461
#
#  End of Epoch Learning Rate = 0.024302
# 400/400 [==============================] - 107s 268ms/step - loss: 1.3861 - acc: 0.7726 - val_loss: 1.8779 - val_acc: 0.6461
#
#  Start of Epoch Learning Rate = 0.024302
# Epoch 106/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 1.9511 - acc: 0.6316
#
#  End of Epoch Learning Rate = 0.022229
# 400/400 [==============================] - 107s 268ms/step - loss: 1.3558 - acc: 0.7769 - val_loss: 1.9511 - val_acc: 0.6316
#
#  Start of Epoch Learning Rate = 0.022229
# Epoch 107/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.8177 - acc: 0.6605
#
#  End of Epoch Learning Rate = 0.020223
# 400/400 [==============================] - 107s 267ms/step - loss: 1.3071 - acc: 0.7869 - val_loss: 1.8177 - val_acc: 0.6605
#
#  Start of Epoch Learning Rate = 0.020223
# Epoch 108/254
# 10000/10000 [==============================] - 6s 622us/sample - loss: 1.9164 - acc: 0.6463
#
#  End of Epoch Learning Rate = 0.018289
# 400/400 [==============================] - 107s 268ms/step - loss: 1.2594 - acc: 0.7981 - val_loss: 1.9164 - val_acc: 0.6463
#
#  Start of Epoch Learning Rate = 0.018289
# Epoch 109/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.6944 - acc: 0.6886
#
#  End of Epoch Learning Rate = 0.016430
# 400/400 [==============================] - 107s 267ms/step - loss: 1.2060 - acc: 0.8102 - val_loss: 1.6944 - val_acc: 0.6886
#
#  Start of Epoch Learning Rate = 0.016430
# Epoch 110/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.7685 - acc: 0.6612
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 107s 267ms/step - loss: 1.1663 - acc: 0.8188 - val_loss: 1.7685 - val_acc: 0.6612
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 111/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 1.5790 - acc: 0.7091
#
#  End of Epoch Learning Rate = 0.012961
# 400/400 [==============================] - 107s 267ms/step - loss: 1.1214 - acc: 0.8298 - val_loss: 1.5790 - val_acc: 0.7091
#
#  Start of Epoch Learning Rate = 0.012961
# Epoch 112/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 1.5488 - acc: 0.7114
#
#  End of Epoch Learning Rate = 0.011358
# 400/400 [==============================] - 107s 267ms/step - loss: 1.0791 - acc: 0.8384 - val_loss: 1.5488 - val_acc: 0.7114
#
#  Start of Epoch Learning Rate = 0.011358
# Epoch 113/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 1.4944 - acc: 0.7284
#
#  End of Epoch Learning Rate = 0.009849
# 400/400 [==============================] - 107s 267ms/step - loss: 1.0366 - acc: 0.8483 - val_loss: 1.4944 - val_acc: 0.7284
#
#  Start of Epoch Learning Rate = 0.009849
# Epoch 114/254
# 10000/10000 [==============================] - 6s 631us/sample - loss: 1.4711 - acc: 0.7255
#
#  End of Epoch Learning Rate = 0.008436
# 400/400 [==============================] - 107s 267ms/step - loss: 0.9899 - acc: 0.8604 - val_loss: 1.4711 - val_acc: 0.7255
#
#  Start of Epoch Learning Rate = 0.008436
# Epoch 115/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.4818 - acc: 0.7317
#
#  End of Epoch Learning Rate = 0.007123
# 400/400 [==============================] - 107s 267ms/step - loss: 0.9420 - acc: 0.8723 - val_loss: 1.4818 - val_acc: 0.7317
#
#  Start of Epoch Learning Rate = 0.007123
# Epoch 116/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.3348 - acc: 0.7616
#
#  End of Epoch Learning Rate = 0.005913
# 400/400 [==============================] - 107s 267ms/step - loss: 0.9069 - acc: 0.8807 - val_loss: 1.3348 - val_acc: 0.7616
#
#  Start of Epoch Learning Rate = 0.005913
# Epoch 117/254
# 10000/10000 [==============================] - 6s 633us/sample - loss: 1.3173 - acc: 0.7638
#
#  End of Epoch Learning Rate = 0.004810
# 400/400 [==============================] - 107s 267ms/step - loss: 0.8632 - acc: 0.8917 - val_loss: 1.3173 - val_acc: 0.7638
#
#  Start of Epoch Learning Rate = 0.004810
# Epoch 118/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 1.2482 - acc: 0.7781
#
#  End of Epoch Learning Rate = 0.003816
# 400/400 [==============================] - 107s 267ms/step - loss: 0.8316 - acc: 0.8984 - val_loss: 1.2482 - val_acc: 0.7781
#
#  Start of Epoch Learning Rate = 0.003816
# Epoch 119/254
# 10000/10000 [==============================] - 6s 624us/sample - loss: 1.2212 - acc: 0.7837
#
#  End of Epoch Learning Rate = 0.002933
# 400/400 [==============================] - 107s 266ms/step - loss: 0.8010 - acc: 0.9076 - val_loss: 1.2212 - val_acc: 0.7837
#
#  Start of Epoch Learning Rate = 0.002933
# Epoch 120/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 1.1809 - acc: 0.7934
#
#  End of Epoch Learning Rate = 0.002163
# 400/400 [==============================] - 107s 268ms/step - loss: 0.7771 - acc: 0.9138 - val_loss: 1.1809 - val_acc: 0.7934
#
#  Start of Epoch Learning Rate = 0.002163
# Epoch 121/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 1.1559 - acc: 0.7964
#
#  End of Epoch Learning Rate = 0.001508
# 400/400 [==============================] - 107s 267ms/step - loss: 0.7449 - acc: 0.9222 - val_loss: 1.1559 - val_acc: 0.7964
#
#  Start of Epoch Learning Rate = 0.001508
# Epoch 122/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.1507 - acc: 0.8023
#
#  End of Epoch Learning Rate = 0.000971
# 400/400 [==============================] - 107s 267ms/step - loss: 0.7289 - acc: 0.9255 - val_loss: 1.1507 - val_acc: 0.8023
#
#  Start of Epoch Learning Rate = 0.000971
# Epoch 123/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 1.1316 - acc: 0.8081
#
#  End of Epoch Learning Rate = 0.000551
# 400/400 [==============================] - 107s 268ms/step - loss: 0.7098 - acc: 0.9294 - val_loss: 1.1316 - val_acc: 0.8081
#
#  Start of Epoch Learning Rate = 0.000551
# Epoch 124/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 1.1204 - acc: 0.8100
#
#  End of Epoch Learning Rate = 0.000251
# 400/400 [==============================] - 107s 267ms/step - loss: 0.6933 - acc: 0.9354 - val_loss: 1.1204 - val_acc: 0.8100
#
#  Start of Epoch Learning Rate = 0.000251
# Epoch 125/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 1.1105 - acc: 0.8096
#
#  End of Epoch Learning Rate = 0.000070
# 400/400 [==============================] - 107s 267ms/step - loss: 0.6865 - acc: 0.9363 - val_loss: 1.1105 - val_acc: 0.8096
#
#  Start of Epoch Learning Rate = 0.000070
# Epoch 126/254
# 10000/10000 [==============================] - 6s 631us/sample - loss: 1.1077 - acc: 0.8117
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 107s 268ms/step - loss: 0.6865 - acc: 0.9354 - val_loss: 1.1077 - val_acc: 0.8117
#
#  Start of Epoch Learning Rate = 0.100000
# Epoch 127/254
# 10000/10000 [==============================] - 6s 624us/sample - loss: 3.9681 - acc: 0.2256
#
#  End of Epoch Learning Rate = 0.099985
# 400/400 [==============================] - 107s 268ms/step - loss: 2.3012 - acc: 0.5514 - val_loss: 3.9681 - val_acc: 0.2256
#
#  Start of Epoch Learning Rate = 0.099985
# Epoch 128/254
# 10000/10000 [==============================] - 6s 627us/sample - loss: 3.3595 - acc: 0.3536
#
#  End of Epoch Learning Rate = 0.099940
# 400/400 [==============================] - 107s 268ms/step - loss: 2.2076 - acc: 0.5881 - val_loss: 3.3595 - val_acc: 0.3536
#
#  Start of Epoch Learning Rate = 0.099940
# Epoch 129/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 3.0362 - acc: 0.4334
#
#  End of Epoch Learning Rate = 0.099865
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1962 - acc: 0.6032 - val_loss: 3.0362 - val_acc: 0.4334
#
#  Start of Epoch Learning Rate = 0.099865
# Epoch 130/254
# 10000/10000 [==============================] - 6s 623us/sample - loss: 3.2398 - acc: 0.3866
#
#  End of Epoch Learning Rate = 0.099759
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1916 - acc: 0.6103 - val_loss: 3.2398 - val_acc: 0.3866
#
#  Start of Epoch Learning Rate = 0.099759
# Epoch 131/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 3.0090 - acc: 0.4383
#
#  End of Epoch Learning Rate = 0.099624
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1890 - acc: 0.6192 - val_loss: 3.0090 - val_acc: 0.4383
#
#  Start of Epoch Learning Rate = 0.099624
# Epoch 132/254
# 10000/10000 [==============================] - 6s 624us/sample - loss: 2.8595 - acc: 0.4661
#
#  End of Epoch Learning Rate = 0.099459
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1973 - acc: 0.6220 - val_loss: 2.8595 - val_acc: 0.4661
#
#  Start of Epoch Learning Rate = 0.099459
# Epoch 133/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 2.9173 - acc: 0.4512
#
#  End of Epoch Learning Rate = 0.099264
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1911 - acc: 0.6246 - val_loss: 2.9173 - val_acc: 0.4512
#
#  Start of Epoch Learning Rate = 0.099264
# Epoch 134/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 2.7473 - acc: 0.5022
#
#  End of Epoch Learning Rate = 0.099039
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1973 - acc: 0.6245 - val_loss: 2.7473 - val_acc: 0.5022
#
#  Start of Epoch Learning Rate = 0.099039
# Epoch 135/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 2.6821 - acc: 0.5175
#
#  End of Epoch Learning Rate = 0.098785
# 400/400 [==============================] - 107s 267ms/step - loss: 2.2207 - acc: 0.6223 - val_loss: 2.6821 - val_acc: 0.5175
#
#  Start of Epoch Learning Rate = 0.098785
# Epoch 136/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 2.7959 - acc: 0.5059
#
#  End of Epoch Learning Rate = 0.098502
# 400/400 [==============================] - 107s 268ms/step - loss: 2.2153 - acc: 0.6238 - val_loss: 2.7959 - val_acc: 0.5059
#
#  Start of Epoch Learning Rate = 0.098502
# Epoch 137/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 3.2187 - acc: 0.4210
#
#  End of Epoch Learning Rate = 0.098189
# 400/400 [==============================] - 107s 266ms/step - loss: 2.2064 - acc: 0.6268 - val_loss: 3.2187 - val_acc: 0.4210
#
#  Start of Epoch Learning Rate = 0.098189
# Epoch 138/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 3.2413 - acc: 0.4027
#
#  End of Epoch Learning Rate = 0.097847
# 400/400 [==============================] - 107s 266ms/step - loss: 2.2062 - acc: 0.6287 - val_loss: 3.2413 - val_acc: 0.4027
#
#  Start of Epoch Learning Rate = 0.097847
# Epoch 139/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 2.9396 - acc: 0.4543
#
#  End of Epoch Learning Rate = 0.097477
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1975 - acc: 0.6285 - val_loss: 2.9396 - val_acc: 0.4543
#
#  Start of Epoch Learning Rate = 0.097477
# Epoch 140/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 3.3269 - acc: 0.4054
#
#  End of Epoch Learning Rate = 0.097077
# 400/400 [==============================] - 107s 266ms/step - loss: 2.1969 - acc: 0.6270 - val_loss: 3.3269 - val_acc: 0.4054
#
#  Start of Epoch Learning Rate = 0.097077
# Epoch 141/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 2.9747 - acc: 0.4598
#
#  End of Epoch Learning Rate = 0.096650
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1954 - acc: 0.6294 - val_loss: 2.9747 - val_acc: 0.4598
#
#  Start of Epoch Learning Rate = 0.096650
# Epoch 142/254
# 10000/10000 [==============================] - 6s 627us/sample - loss: 3.1428 - acc: 0.4258
#
#  End of Epoch Learning Rate = 0.096194
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1909 - acc: 0.6306 - val_loss: 3.1428 - val_acc: 0.4258
#
#  Start of Epoch Learning Rate = 0.096194
# Epoch 143/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 3.2773 - acc: 0.4005
#
#  End of Epoch Learning Rate = 0.095711
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1924 - acc: 0.6303 - val_loss: 3.2773 - val_acc: 0.4005
#
#  Start of Epoch Learning Rate = 0.095711
# Epoch 144/254
# 10000/10000 [==============================] - 6s 622us/sample - loss: 2.8684 - acc: 0.4706
#
#  End of Epoch Learning Rate = 0.095200
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1799 - acc: 0.6292 - val_loss: 2.8684 - val_acc: 0.4706
#
#  Start of Epoch Learning Rate = 0.095200
# Epoch 145/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 2.7830 - acc: 0.4993
#
#  End of Epoch Learning Rate = 0.094662
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1837 - acc: 0.6307 - val_loss: 2.7830 - val_acc: 0.4993
#
#  Start of Epoch Learning Rate = 0.094662
# Epoch 146/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 3.1949 - acc: 0.4136
#
#  End of Epoch Learning Rate = 0.094097
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1740 - acc: 0.6320 - val_loss: 3.1949 - val_acc: 0.4136
#
#  Start of Epoch Learning Rate = 0.094097
# Epoch 147/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 2.9972 - acc: 0.4436
#
#  End of Epoch Learning Rate = 0.093505
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1706 - acc: 0.6329 - val_loss: 2.9972 - val_acc: 0.4436
#
#  Start of Epoch Learning Rate = 0.093505
# Epoch 148/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 2.8483 - acc: 0.4692
#
#  End of Epoch Learning Rate = 0.092887
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1632 - acc: 0.6327 - val_loss: 2.8483 - val_acc: 0.4692
#
#  Start of Epoch Learning Rate = 0.092887
# Epoch 149/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 3.0977 - acc: 0.4373
#
#  End of Epoch Learning Rate = 0.092243
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1503 - acc: 0.6381 - val_loss: 3.0977 - val_acc: 0.4373
#
#  Start of Epoch Learning Rate = 0.092243
# Epoch 150/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 2.7985 - acc: 0.4809
#
#  End of Epoch Learning Rate = 0.091574
# 400/400 [==============================] - 107s 268ms/step - loss: 2.1490 - acc: 0.6372 - val_loss: 2.7985 - val_acc: 0.4809
#
#  Start of Epoch Learning Rate = 0.091574
# Epoch 151/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 2.9735 - acc: 0.4544
#
#  End of Epoch Learning Rate = 0.090880
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1292 - acc: 0.6425 - val_loss: 2.9735 - val_acc: 0.4544
#
#  Start of Epoch Learning Rate = 0.090880
# Epoch 152/254
# 10000/10000 [==============================] - 6s 615us/sample - loss: 2.8518 - acc: 0.4847
#
#  End of Epoch Learning Rate = 0.090161
# 400/400 [==============================] - 107s 267ms/step - loss: 2.1346 - acc: 0.6368 - val_loss: 2.8518 - val_acc: 0.4847
#
#  Start of Epoch Learning Rate = 0.090161
# Epoch 153/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 3.1686 - acc: 0.4132
#
#  End of Epoch Learning Rate = 0.089418
# ...
#
#  Start of Epoch Learning Rate = 0.034322
# Epoch 204/254
# 10000/10000 [==============================] - 6s 614us/sample - loss: 2.0309 - acc: 0.6232
#
#  End of Epoch Learning Rate = 0.033162
# 400/400 [==============================] - 107s 268ms/step - loss: 1.4776 - acc: 0.7540 - val_loss: 2.0309 - val_acc: 0.6232
#
#  Start of Epoch Learning Rate = 0.033162
# Epoch 205/254
# 10000/10000 [==============================] - 6s 611us/sample - loss: 1.9739 - acc: 0.6397
#
#  End of Epoch Learning Rate = 0.032012
# 400/400 [==============================] - 107s 267ms/step - loss: 1.4581 - acc: 0.7554 - val_loss: 1.9739 - val_acc: 0.6397
#
#  Start of Epoch Learning Rate = 0.032012
# Epoch 206/254
# 10000/10000 [==============================] - 6s 625us/sample - loss: 2.1011 - acc: 0.6124
#
#  End of Epoch Learning Rate = 0.030873
# 400/400 [==============================] - 107s 268ms/step - loss: 1.4302 - acc: 0.7642 - val_loss: 2.1011 - val_acc: 0.6124
#
#  Start of Epoch Learning Rate = 0.030873
# Epoch 207/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 2.0593 - acc: 0.6080
#
#  End of Epoch Learning Rate = 0.029745
# 400/400 [==============================] - 107s 268ms/step - loss: 1.4121 - acc: 0.7660 - val_loss: 2.0593 - val_acc: 0.6080
#
#  Start of Epoch Learning Rate = 0.029745
# Epoch 208/254
# 10000/10000 [==============================] - 6s 624us/sample - loss: 2.1158 - acc: 0.5973
#
#  End of Epoch Learning Rate = 0.028629
# 400/400 [==============================] - 107s 268ms/step - loss: 1.3826 - acc: 0.7736 - val_loss: 2.1158 - val_acc: 0.5973
#
#  Start of Epoch Learning Rate = 0.028629
# Epoch 209/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 2.1097 - acc: 0.6097
#
#  End of Epoch Learning Rate = 0.027527
# 400/400 [==============================] - 107s 267ms/step - loss: 1.3727 - acc: 0.7741 - val_loss: 2.1097 - val_acc: 0.6097
#
#  Start of Epoch Learning Rate = 0.027527
# Epoch 210/254
# 10000/10000 [==============================] - 6s 627us/sample - loss: 2.0173 - acc: 0.6146
#
#  End of Epoch Learning Rate = 0.026438
# 400/400 [==============================] - 107s 267ms/step - loss: 1.3458 - acc: 0.7800 - val_loss: 2.0173 - val_acc: 0.6146
#
#  Start of Epoch Learning Rate = 0.026438
# Epoch 211/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 2.1787 - acc: 0.5973
#
#  End of Epoch Learning Rate = 0.025363
# 400/400 [==============================] - 107s 267ms/step - loss: 1.3242 - acc: 0.7828 - val_loss: 2.1787 - val_acc: 0.5973
#
#  Start of Epoch Learning Rate = 0.025363
# Epoch 212/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 1.8297 - acc: 0.6550
#
#  End of Epoch Learning Rate = 0.024302
# 400/400 [==============================] - 107s 267ms/step - loss: 1.2968 - acc: 0.7886 - val_loss: 1.8297 - val_acc: 0.6550
#
#  Start of Epoch Learning Rate = 0.024302
# Epoch 213/254
# 10000/10000 [==============================] - 6s 625us/sample - loss: 2.0087 - acc: 0.6285
#
#  End of Epoch Learning Rate = 0.023258
# 400/400 [==============================] - 107s 267ms/step - loss: 1.2799 - acc: 0.7920 - val_loss: 2.0087 - val_acc: 0.6285
#
#  Start of Epoch Learning Rate = 0.023258
# Epoch 214/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 1.9237 - acc: 0.6402
#
#  End of Epoch Learning Rate = 0.022229
# 400/400 [==============================] - 107s 267ms/step - loss: 1.2613 - acc: 0.7969 - val_loss: 1.9237 - val_acc: 0.6402
#
#  Start of Epoch Learning Rate = 0.022229
# Epoch 215/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 1.8270 - acc: 0.6527
#
#  End of Epoch Learning Rate = 0.021217
# 400/400 [==============================] - 107s 267ms/step - loss: 1.2415 - acc: 0.8026 - val_loss: 1.8270 - val_acc: 0.6527
#
#  Start of Epoch Learning Rate = 0.021217
# Epoch 216/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 1.8401 - acc: 0.6689
#
#  End of Epoch Learning Rate = 0.020223
# 400/400 [==============================] - 107s 268ms/step - loss: 1.2067 - acc: 0.8097 - val_loss: 1.8401 - val_acc: 0.6689
#
#  Start of Epoch Learning Rate = 0.020223
# Epoch 217/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 1.9189 - acc: 0.6414
#
#  End of Epoch Learning Rate = 0.019246
# 400/400 [==============================] - 107s 267ms/step - loss: 1.1786 - acc: 0.8144 - val_loss: 1.9189 - val_acc: 0.6414
#
#  Start of Epoch Learning Rate = 0.019246
# Epoch 218/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.7440 - acc: 0.6657
#
#  End of Epoch Learning Rate = 0.018289
# 400/400 [==============================] - 107s 266ms/step - loss: 1.1625 - acc: 0.8177 - val_loss: 1.7440 - val_acc: 0.6657
#
#  Start of Epoch Learning Rate = 0.018289
# Epoch 219/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.7156 - acc: 0.6897
#
#  End of Epoch Learning Rate = 0.017350
# 400/400 [==============================] - 107s 268ms/step - loss: 1.1292 - acc: 0.8250 - val_loss: 1.7156 - val_acc: 0.6897
#
#  Start of Epoch Learning Rate = 0.017350
# Epoch 220/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 1.7513 - acc: 0.6723
#
#  End of Epoch Learning Rate = 0.016430
# 400/400 [==============================] - 107s 268ms/step - loss: 1.1039 - acc: 0.8310 - val_loss: 1.7513 - val_acc: 0.6723
#
#  Start of Epoch Learning Rate = 0.016430
# Epoch 221/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 1.6571 - acc: 0.6817
#
#  End of Epoch Learning Rate = 0.015531
# 400/400 [==============================] - 107s 267ms/step - loss: 1.0762 - acc: 0.8380 - val_loss: 1.6571 - val_acc: 0.6817
#
#  Start of Epoch Learning Rate = 0.015531
# Epoch 222/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 1.8576 - acc: 0.6566
#
#  End of Epoch Learning Rate = 0.014653
# 400/400 [==============================] - 107s 267ms/step - loss: 1.0632 - acc: 0.8400 - val_loss: 1.8576 - val_acc: 0.6566
#
#  Start of Epoch Learning Rate = 0.014653
# Epoch 223/254
# 10000/10000 [==============================] - 6s 612us/sample - loss: 1.6854 - acc: 0.6853
#
#  End of Epoch Learning Rate = 0.013796
# 400/400 [==============================] - 107s 267ms/step - loss: 1.0352 - acc: 0.8465 - val_loss: 1.6854 - val_acc: 0.6853
#
#  Start of Epoch Learning Rate = 0.013796
# Epoch 224/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.7524 - acc: 0.6752
#
#  End of Epoch Learning Rate = 0.012961
# 400/400 [==============================] - 107s 266ms/step - loss: 1.0048 - acc: 0.8519 - val_loss: 1.7524 - val_acc: 0.6752
#
#  Start of Epoch Learning Rate = 0.012961
# Epoch 225/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 1.5314 - acc: 0.7230
#
#  End of Epoch Learning Rate = 0.012148
# 400/400 [==============================] - 107s 268ms/step - loss: 0.9862 - acc: 0.8569 - val_loss: 1.5314 - val_acc: 0.7230
#
#  Start of Epoch Learning Rate = 0.012148
# Epoch 226/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.5103 - acc: 0.7102
#
#  End of Epoch Learning Rate = 0.011358
# 400/400 [==============================] - 107s 268ms/step - loss: 0.9614 - acc: 0.8628 - val_loss: 1.5103 - val_acc: 0.7102
#
#  Start of Epoch Learning Rate = 0.011358
# Epoch 227/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.4708 - acc: 0.7251
#
#  End of Epoch Learning Rate = 0.010592
# 400/400 [==============================] - 107s 267ms/step - loss: 0.9352 - acc: 0.8682 - val_loss: 1.4708 - val_acc: 0.7251
#
#  Start of Epoch Learning Rate = 0.010592
# Epoch 228/254
# 10000/10000 [==============================] - 6s 617us/sample - loss: 1.5742 - acc: 0.7057
#
#  End of Epoch Learning Rate = 0.009849
# 400/400 [==============================] - 107s 268ms/step - loss: 0.9062 - acc: 0.8748 - val_loss: 1.5742 - val_acc: 0.7057
#
#  Start of Epoch Learning Rate = 0.009849
# Epoch 229/254
# 10000/10000 [==============================] - 6s 627us/sample - loss: 1.4309 - acc: 0.7341
#
#  End of Epoch Learning Rate = 0.009130
# 400/400 [==============================] - 108s 269ms/step - loss: 0.8859 - acc: 0.8810 - val_loss: 1.4309 - val_acc: 0.7341
#
#  Start of Epoch Learning Rate = 0.009130
# Epoch 230/254
# 10000/10000 [==============================] - 6s 618us/sample - loss: 1.4068 - acc: 0.7422
#
#  End of Epoch Learning Rate = 0.008436
# 400/400 [==============================] - 107s 268ms/step - loss: 0.8632 - acc: 0.8858 - val_loss: 1.4068 - val_acc: 0.7422
#
#  Start of Epoch Learning Rate = 0.008436
# Epoch 231/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 1.4360 - acc: 0.7348
#
#  End of Epoch Learning Rate = 0.007767
# 400/400 [==============================] - 107s 267ms/step - loss: 0.8337 - acc: 0.8921 - val_loss: 1.4360 - val_acc: 0.7348
#
#  Start of Epoch Learning Rate = 0.007767
# Epoch 232/254
# 10000/10000 [==============================] - 6s 628us/sample - loss: 1.3773 - acc: 0.7523
#
#  End of Epoch Learning Rate = 0.007123
# 400/400 [==============================] - 107s 268ms/step - loss: 0.8069 - acc: 0.8980 - val_loss: 1.3773 - val_acc: 0.7523
#
#  Start of Epoch Learning Rate = 0.007123
# Epoch 233/254
# 10000/10000 [==============================] - 6s 624us/sample - loss: 1.2982 - acc: 0.7676
#
#  End of Epoch Learning Rate = 0.006505
# 400/400 [==============================] - 108s 269ms/step - loss: 0.7805 - acc: 0.9033 - val_loss: 1.2982 - val_acc: 0.7676
#
#  Start of Epoch Learning Rate = 0.006505
# Epoch 234/254
# 10000/10000 [==============================] - 6s 627us/sample - loss: 1.3394 - acc: 0.7585
#
#  End of Epoch Learning Rate = 0.005913
# 400/400 [==============================] - 107s 267ms/step - loss: 0.7678 - acc: 0.9069 - val_loss: 1.3394 - val_acc: 0.7585
#
#  Start of Epoch Learning Rate = 0.005913
# Epoch 235/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.3247 - acc: 0.7595
#
#  End of Epoch Learning Rate = 0.005348
# 400/400 [==============================] - 107s 268ms/step - loss: 0.7421 - acc: 0.9136 - val_loss: 1.3247 - val_acc: 0.7595
#
#  Start of Epoch Learning Rate = 0.005348
# Epoch 236/254
# 10000/10000 [==============================] - 6s 630us/sample - loss: 1.2661 - acc: 0.7714
#
#  End of Epoch Learning Rate = 0.004810
# 400/400 [==============================] - 107s 267ms/step - loss: 0.7279 - acc: 0.9160 - val_loss: 1.2661 - val_acc: 0.7714
#
#  Start of Epoch Learning Rate = 0.004810
# Epoch 237/254
# 10000/10000 [==============================] - 6s 624us/sample - loss: 1.2698 - acc: 0.7717
#
#  End of Epoch Learning Rate = 0.004299
# 400/400 [==============================] - 107s 266ms/step - loss: 0.7029 - acc: 0.9221 - val_loss: 1.2698 - val_acc: 0.7717
#
#  Start of Epoch Learning Rate = 0.004299
# Epoch 238/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 1.2504 - acc: 0.7742
#
#  End of Epoch Learning Rate = 0.003816
# 400/400 [==============================] - 107s 267ms/step - loss: 0.6780 - acc: 0.9284 - val_loss: 1.2504 - val_acc: 0.7742
#
#  Start of Epoch Learning Rate = 0.003816
# Epoch 239/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 1.2598 - acc: 0.7797
#
#  End of Epoch Learning Rate = 0.003360
# 400/400 [==============================] - 107s 267ms/step - loss: 0.6654 - acc: 0.9305 - val_loss: 1.2598 - val_acc: 0.7797
#
#  Start of Epoch Learning Rate = 0.003360
# Epoch 240/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.1981 - acc: 0.7887
#
#  End of Epoch Learning Rate = 0.002933
# 400/400 [==============================] - 107s 268ms/step - loss: 0.6564 - acc: 0.9323 - val_loss: 1.1981 - val_acc: 0.7887
#
#  Start of Epoch Learning Rate = 0.002933
# Epoch 241/254
# 10000/10000 [==============================] - 6s 622us/sample - loss: 1.1861 - acc: 0.7871
#
#  End of Epoch Learning Rate = 0.002533
# 400/400 [==============================] - 107s 267ms/step - loss: 0.6353 - acc: 0.9376 - val_loss: 1.1861 - val_acc: 0.7871
#
#  Start of Epoch Learning Rate = 0.002533
# Epoch 242/254
# 10000/10000 [==============================] - 6s 625us/sample - loss: 1.1675 - acc: 0.7935
#
#  End of Epoch Learning Rate = 0.002163
# 400/400 [==============================] - 107s 268ms/step - loss: 0.6203 - acc: 0.9420 - val_loss: 1.1675 - val_acc: 0.7935
#
#  Start of Epoch Learning Rate = 0.002163
# Epoch 243/254
# 10000/10000 [==============================] - 6s 619us/sample - loss: 1.1619 - acc: 0.7932
#
#  End of Epoch Learning Rate = 0.001821
# 400/400 [==============================] - 107s 268ms/step - loss: 0.6088 - acc: 0.9440 - val_loss: 1.1619 - val_acc: 0.7932
#
#  Start of Epoch Learning Rate = 0.001821
# Epoch 244/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 1.1551 - acc: 0.7980
#
#  End of Epoch Learning Rate = 0.001508
# 400/400 [==============================] - 107s 268ms/step - loss: 0.5996 - acc: 0.9455 - val_loss: 1.1551 - val_acc: 0.7980
#
#  Start of Epoch Learning Rate = 0.001508
# Epoch 245/254
# 10000/10000 [==============================] - 6s 625us/sample - loss: 1.1130 - acc: 0.8054
#
#  End of Epoch Learning Rate = 0.001225
# 400/400 [==============================] - 107s 268ms/step - loss: 0.5876 - acc: 0.9483 - val_loss: 1.1130 - val_acc: 0.8054
#
#  Start of Epoch Learning Rate = 0.001225
# Epoch 246/254
# 10000/10000 [==============================] - 6s 626us/sample - loss: 1.1089 - acc: 0.8074
#
#  End of Epoch Learning Rate = 0.000971
# 400/400 [==============================] - 107s 267ms/step - loss: 0.5763 - acc: 0.9511 - val_loss: 1.1089 - val_acc: 0.8074
#
#  Start of Epoch Learning Rate = 0.000971
# Epoch 247/254
# 10000/10000 [==============================] - 6s 631us/sample - loss: 1.1142 - acc: 0.8099
#
#  End of Epoch Learning Rate = 0.000746
# 400/400 [==============================] - 107s 267ms/step - loss: 0.5710 - acc: 0.9525 - val_loss: 1.1142 - val_acc: 0.8099
#
#  Start of Epoch Learning Rate = 0.000746
# Epoch 248/254
# 10000/10000 [==============================] - 6s 629us/sample - loss: 1.0902 - acc: 0.8149
#
#  End of Epoch Learning Rate = 0.000551
# 400/400 [==============================] - 107s 267ms/step - loss: 0.5612 - acc: 0.9552 - val_loss: 1.0902 - val_acc: 0.8149
#
#  Start of Epoch Learning Rate = 0.000551
# Epoch 249/254
# 10000/10000 [==============================] - 6s 621us/sample - loss: 1.0849 - acc: 0.8112
#
#  End of Epoch Learning Rate = 0.000386
# 400/400 [==============================] - 107s 267ms/step - loss: 0.5563 - acc: 0.9554 - val_loss: 1.0849 - val_acc: 0.8112
#
#  Start of Epoch Learning Rate = 0.000386
# Epoch 250/254
# 10000/10000 [==============================] - 6s 613us/sample - loss: 1.0859 - acc: 0.8143
#
#  End of Epoch Learning Rate = 0.000251
# 400/400 [==============================] - 107s 267ms/step - loss: 0.5517 - acc: 0.9565 - val_loss: 1.0859 - val_acc: 0.8143
#
#  Start of Epoch Learning Rate = 0.000251
# Epoch 251/254
# 10000/10000 [==============================] - 6s 636us/sample - loss: 1.0707 - acc: 0.8165
#
#  End of Epoch Learning Rate = 0.000145
# 400/400 [==============================] - 107s 267ms/step - loss: 0.5458 - acc: 0.9579 - val_loss: 1.0707 - val_acc: 0.8165
#
#  Start of Epoch Learning Rate = 0.000145
# Epoch 252/254
# 10000/10000 [==============================] - 6s 616us/sample - loss: 1.0691 - acc: 0.8186
#
#  End of Epoch Learning Rate = 0.000070
# 400/400 [==============================] - 107s 268ms/step - loss: 0.5370 - acc: 0.9600 - val_loss: 1.0691 - val_acc: 0.8186
#
#  Start of Epoch Learning Rate = 0.000070
# Epoch 253/254
# 10000/10000 [==============================] - 6s 620us/sample - loss: 1.0708 - acc: 0.8180
#
#  End of Epoch Learning Rate = 0.000025
# 400/400 [==============================] - 107s 268ms/step - loss: 0.5382 - acc: 0.9592 - val_loss: 1.0708 - val_acc: 0.8180
#
#  Start of Epoch Learning Rate = 0.000025
# Epoch 254/254
# 10000/10000 [==============================] - 6s 631us/sample - loss: 1.0667 - acc: 0.8183
#
#  End of Epoch Learning Rate = 0.000010
# 400/400 [==============================] - 107s 267ms/step - loss: 0.5312 - acc: 0.9601 - val_loss: 1.0667 - val_acc: 0.8183

# %%
#get final performance
y_pred = model.predict(x_test)
print('Test accuracy (%):', 100*sum(np.argmax(y_pred,-1)==np.argmax(y_test,-1))/y_test.shape[0])
# Out:
# Test accuracy (%): 81.83

# %%
#plot loss and accuracy
plot_history(model.history.history)

#plot learning rate schedule
plt.figure(figsize=(16,4))
plt.plot(np.arange(0,len(lr_scheduler.lr_used))/steps_per_epoch,lr_scheduler.lr_used)
plt.xlabel('epoch number')
plt.ylabel('learning rate')
plt.show()

# %%
#save the weigts used for updating
model.save_weights(ModelsPath+'Final_weights_'+WhichDataSet+'_OneBitPerWeight_model_v2.h5')

# %%
#create an inference model that uses regular conv2d layers
inference_model = resnet(UseBinaryWeights=False,input_shape=input_shape, depth=resnet_depth, num_classes=num_classes,wd=My_wd,width=resnet_width)
inference_model.compile(loss=Loss ,optimizer = Optimizer, metrics = Metrics)
inference_model.load_weights(ModelsPath+'Final_weights_'+WhichDataSet+'_OneBitPerWeight_model_v2.h5')

#get accuracy:
y_pred = inference_model.predict(x_test)
print('Test accuracy (%):', 100*sum(np.argmax(y_pred,-1)==np.argmax(y_test,-1))/y_test.shape[0])

#doesn't work yet because sign and scale not yet applied, as we set UseBinaryWeights=False for inference_model
# Out:
# Test accuracy (%): 1.0

# %%
#convert weights to one bit storage in python and copy into the inference model

ZeroOneWeightsDict = {}
AllParamsDict={}
NumBinaryWeights=0.0
for layer in inference_model.layers:
    #print(layer.name)

    if 'conv2d' in layer.name:
        ww=layer.get_weights()
        layer.set_weights(np.sign(ww)*np.sqrt(2.0/np.prod(ww[0].shape[0:3])))
        
        #storage using 1 bit booleans
        binary_weights = (0.5*(np.sign(ww)+1.0)).astype('bool')
        ZeroOneWeightsDict[layer.name]=binary_weights
        AllParamsDict[layer.name]=binary_weights
        NumBinaryWeights+=np.prod(ww[0].shape)
    elif 'batch_normalization' in layer.name:
        #the saved model also nees floating point batch norm params
        ww=layer.get_weights()
        AllParamsDict[layer.name]=ww
        
savemat(ModelsPath+WhichDataSet+'_01weights.mat',ZeroOneWeightsDict,do_compression=True,long_field_names=True)
savemat(ModelsPath+WhichDataSet+'_allparams.mat',AllParamsDict,do_compression=True,long_field_names=True)
inference_model.save_weights(ModelsPath+'Final_weights_'+WhichDataSet+'_binarized.h5')

WeightsMemory=NumBinaryWeights/8/1024/1024
print('Num binary weights = ',int(NumBinaryWeights),'; weights memory = ',WeightsMemory,'  MB')

#get accuracy:
y_pred = inference_model.predict(x_test)
print('Test accuracy (%):', 100*sum(np.argmax(y_pred,-1)==np.argmax(y_test,-1))/y_test.shape[0])
# Out:
# Num binary weights =  26794720 ; weights memory =  3.1941795349121094   MB
# Test accuracy (%): 81.83

# %%
#verify 1 bit weights work perfectly when loaded from h5 file

inference_model.load_weights(ModelsPath+'Final_weights_'+WhichDataSet+'_binarized.h5')

#verify each layer can take only two values:
cc=0
for layer in inference_model.layers:
    if 'conv2d' in layer.name:
        
        ww=layer.get_weights()
        uw = np.unique(ww)
        print('conv layer ',cc,' has ', len(uw),' unique weights')
        cc=cc+1

#get accuracy:
y_pred = inference_model.predict(x_test)
print('Test accuracy (%):', 100*sum(np.argmax(y_pred,-1)==np.argmax(y_test,-1))/y_test.shape[0])
# Out:
# conv layer  0  has  2  unique weights
# conv layer  1  has  2  unique weights
# conv layer  2  has  2  unique weights
# conv layer  3  has  2  unique weights
# conv layer  4  has  2  unique weights
# conv layer  5  has  2  unique weights
# conv layer  6  has  2  unique weights
# conv layer  7  has  2  unique weights
# conv layer  8  has  2  unique weights
# conv layer  9  has  2  unique weights
# conv layer  10  has  2  unique weights
# conv layer  11  has  2  unique weights
# conv layer  12  has  2  unique weights
# conv layer  13  has  2  unique weights
# conv layer  14  has  2  unique weights
# conv layer  15  has  2  unique weights
# conv layer  16  has  2  unique weights
# conv layer  17  has  2  unique weights
# conv layer  18  has  2  unique weights
# conv layer  19  has  2  unique weights
# Test accuracy (%): 81.83

# %%
#verify get the same results from compressed boolean storage
AllParamsDict_loaded=loadmat(ModelsPath+WhichDataSet+'_allparams.mat')


#verify each layer can take only two values:
#this requires layers saved with the same name as the most recently defined model
cc=0
for layer in inference_model.layers:
    if 'conv2d' in layer.name:
        ww=AllParamsDict_loaded[layer.name].astype('float32')*2.0-1.0
        ww=ww*np.sqrt(2.0/np.prod(ww[0].shape[0:3]))
        layer.set_weights([ww[0]])
        uw = np.unique(ww)
        print('conv layer ',cc,' has ', len(uw),' unique weights')
        cc=cc+1
    elif 'batch_normalization' in layer.name:
        #as a shortcut for this demo, note we already have the BN weights in the model
        #its a bit tedious wth .mat format to deal with the fact that BN layers can have a list of weights
        pass


#get accuracy:
y_pred = inference_model.predict(x_test)
print('Test accuracy (%):', 100*sum(np.argmax(y_pred,-1)==np.argmax(y_test,-1))/y_test.shape[0])
# Out:
# conv layer  0  has  2  unique weights
# conv layer  1  has  2  unique weights
# conv layer  2  has  2  unique weights
# conv layer  3  has  2  unique weights
# conv layer  4  has  2  unique weights
# conv layer  5  has  2  unique weights
# conv layer  6  has  2  unique weights
# conv layer  7  has  2  unique weights
# conv layer  8  has  2  unique weights
# conv layer  9  has  2  unique weights
# conv layer  10  has  2  unique weights
# conv layer  11  has  2  unique weights
# conv layer  12  has  2  unique weights
# conv layer  13  has  2  unique weights
# conv layer  14  has  2  unique weights
# conv layer  15  has  2  unique weights
# conv layer  16  has  2  unique weights
# conv layer  17  has  2  unique weights
# conv layer  18  has  2  unique weights
# conv layer  19  has  2  unique weights
# Test accuracy (%): 81.83
